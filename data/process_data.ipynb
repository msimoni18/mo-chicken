# %%
import os
import re
import glob
import json
from pathlib import Path
import pandas as pd

def convert_to_list_of_lists(input_list, chunk_size):
    result = [input_list[i:i + chunk_size]
                for i in range(0, len(input_list), chunk_size)] 
    return result

def natural_sort(l): 
    convert = lambda text: int(text) if text.isdigit() else text.lower()
    alphanum_key = lambda key: [convert(c) for c in re.split('([0-9]+)', key)]
    return sorted(l, key=alphanum_key)

# %% [markdown]
# # BEFORE RUNNING, DO THE FOLLOWING:
# - Make sure to adjust headers in standings.txt
# - Make sure 'vs Bye' appears on separate lines. Usually happens
#   for the week where the first round of playoffs occurs.
# - Delete special characters for medals in standings.txt

# %%
df_managers = pd.read_excel('team_names.xlsx', sheet_name='Names')
df_managers
# Out:
#                      team manager  year
# 0          AK shine squad      AK  2014
# 1        Ashley's Pouncey    Burg  2014
# 2           Down Set Smut   Ciggy  2014
# 3    Can I Get Some Reps?     Het  2014
# 4             WE DEM BOYZ    Kyle  2014
# ..                    ...     ...   ...
# 107     Sergeant Friendly    Masi  2024
# 108   AngelLikeMoniBoloni    Moni  2024
# 109            Auto draft   Shoey  2024
# 110         Mollywhoppers    Stew  2024
# 111            Shmo Stars    Zach  2024
#
# [112 rows x 3 columns]

# %% [markdown]
# # Weekly stats

# %%
def parse_weekly_matchups(filename):
    print(filename)

    year = Path(filename).parent.name
    week = os.path.splitext(os.path.basename(filename))[0][4:]

    with open(filename) as file_in:
        content = file_in.read()

        content = content.replace('\t', '')
        content = content.split('\n')

        # Remove headers if they exist
        try:
            content.pop(content.index('Championship Bracket'))
        except ValueError:
            pass
    
        try:
            content.pop(content.index('Consolation Bracket'))
        except ValueError:
            pass
    
    # Check for bye weeks and add dummy data so convert_to_list_of_lists
    # does not need to be modified.
    byes = [i for i, c in enumerate(content) if 'Bye' in c]
    
    if byes:
        byes.reverse()
        for index in byes:
            for i in range(1, 6):
                content.insert(index+i, 'DUMMY')

    # Stuff to do for the playoff weeks
    if content[0] == '':
        content.pop(0)

    lists = convert_to_list_of_lists(content, chunk_size=13)

    weekly_stats = []
    for l in lists:
        new_list = [l[0]] + l[4:9] + [l[11]]

        team1 = new_list[:3]
        team1.insert(0, week)
        team1.insert(0, year)
        weekly_stats.append(team1)

        team2 = new_list[4:]
        if 'Bye' not in team2:
            team2.insert(0, team2.pop())
            team2.insert(0, week)
            team2.insert(0, year)
            weekly_stats.append(team2)

    return weekly_stats


weekly_files = natural_sort(glob.glob('./seasons/*/week*.txt'))

scores = []
for f in weekly_files: 
    week = int(os.path.splitext(os.path.basename(f))[0][4:])
    weekly_score = parse_weekly_matchups(f)
    for row in weekly_score:
        scores.append(row)


df = pd.DataFrame(scores, columns=['year', 'week', 'team', 'points', 'estimated points'])
df['year'] = df['year'].astype(int)
df['week'] = df['week'].astype(int)
df['points'] = df['points'].astype(float)
df['estimated points'] = df['estimated points'].astype(float)

# merge owners
df_weekly = df.merge(df_managers, on=['team', 'year'])
df_weekly = df_weekly.sort_values(['manager', 'year', 'week'], ascending=[True, True, True], ignore_index=True)
df_weekly
# Out:
# ./seasons/2014/week1.txt
# ./seasons/2014/week2.txt
# ./seasons/2014/week3.txt
# ./seasons/2014/week4.txt
# ./seasons/2014/week5.txt
# ./seasons/2014/week6.txt
# ./seasons/2014/week7.txt
# ./seasons/2014/week8.txt
# ./seasons/2014/week9.txt
# ./seasons/2014/week10.txt
# ./seasons/2014/week11.txt
# ./seasons/2014/week12.txt
# ./seasons/2014/week13.txt
# ./seasons/2014/week14.txt
# ./seasons/2014/week15.txt
# ./seasons/2014/week16.txt
# ./seasons/2015/week1.txt
# ./seasons/2015/week2.txt
# ./seasons/2015/week3.txt
# ./seasons/2015/week4.txt
# ./seasons/2015/week5.txt
# ./seasons/2015/week6.txt
# ./seasons/2015/week7.txt
# ./seasons/2015/week8.txt
# ./seasons/2015/week9.txt
# ./seasons/2015/week10.txt
# ./seasons/2015/week11.txt
# ./seasons/2015/week12.txt
# ./seasons/2015/week13.txt
# ./seasons/2015/week14.txt
# ./seasons/2015/week15.txt
# ./seasons/2015/week16.txt
# ./seasons/2016/week1.txt
# ./seasons/2016/week2.txt
# ./seasons/2016/week3.txt
# ./seasons/2016/week4.txt
# ./seasons/2016/week5.txt
# ./seasons/2016/week6.txt
# ./seasons/2016/week7.txt
# ./seasons/2016/week8.txt
# ./seasons/2016/week9.txt
# ./seasons/2016/week10.txt
# ./seasons/2016/week11.txt
# ./seasons/2016/week12.txt
# ./seasons/2016/week13.txt
# ./seasons/2016/week14.txt
# ./seasons/2016/week15.txt
# ./seasons/2016/week16.txt
# ./seasons/2017/week1.txt
# ./seasons/2017/week2.txt
# ./seasons/2017/week3.txt
# ./seasons/2017/week4.txt
# ./seasons/2017/week5.txt
# ./seasons/2017/week6.txt
# ./seasons/2017/week7.txt
# ./seasons/2017/week8.txt
# ./seasons/2017/week9.txt
# ./seasons/2017/week10.txt
# ./seasons/2017/week11.txt
# ./seasons/2017/week12.txt
# ./seasons/2017/week13.txt
# ./seasons/2017/week14.txt
# ./seasons/2017/week15.txt
# ./seasons/2017/week16.txt
# ./seasons/2018/week1.txt
# ./seasons/2018/week2.txt
# ./seasons/2018/week3.txt
# ./seasons/2018/week4.txt
# ./seasons/2018/week5.txt
# ./seasons/2018/week6.txt
# ./seasons/2018/week7.txt
# ./seasons/2018/week8.txt
# ./seasons/2018/week9.txt
# ./seasons/2018/week10.txt
# ./seasons/2018/week11.txt
# ./seasons/2018/week12.txt
# ./seasons/2018/week13.txt
# ./seasons/2018/week14.txt
# ./seasons/2018/week15.txt
# ./seasons/2018/week16.txt
# ./seasons/2019/week1.txt
# ./seasons/2019/week2.txt
# ./seasons/2019/week3.txt
# ./seasons/2019/week4.txt
# ./seasons/2019/week5.txt
# ./seasons/2019/week6.txt
# ./seasons/2019/week7.txt
# ./seasons/2019/week8.txt
# ./seasons/2019/week9.txt
# ./seasons/2019/week10.txt
# ./seasons/2019/week11.txt
# ./seasons/2019/week12.txt
# ./seasons/2019/week13.txt
# ./seasons/2019/week14.txt
# ./seasons/2019/week15.txt
# ./seasons/2019/week16.txt
# ./seasons/2020/week1.txt
# ./seasons/2020/week2.txt
# ./seasons/2020/week3.txt
# ./seasons/2020/week4.txt
# ./seasons/2020/week5.txt
# ./seasons/2020/week6.txt
# ./seasons/2020/week7.txt
# ./seasons/2020/week8.txt
# ./seasons/2020/week9.txt
# ./seasons/2020/week10.txt
# ./seasons/2020/week11.txt
# ./seasons/2020/week12.txt
# ./seasons/2020/week13.txt
# ./seasons/2020/week14.txt
# ./seasons/2020/week15.txt
# ./seasons/2020/week16.txt
# ./seasons/2021/week1.txt
# ./seasons/2021/week2.txt
# ./seasons/2021/week3.txt
# ./seasons/2021/week4.txt
# ./seasons/2021/week5.txt
# ./seasons/2021/week6.txt
# ./seasons/2021/week7.txt
# ./seasons/2021/week8.txt
# ./seasons/2021/week9.txt
# ./seasons/2021/week10.txt
# ./seasons/2021/week11.txt
# ./seasons/2021/week12.txt
# ./seasons/2021/week13.txt
# ./seasons/2021/week14.txt
# ./seasons/2021/week15.txt
# ./seasons/2021/week16.txt
# ./seasons/2021/week17.txt
# ./seasons/2022/week1.txt
# ./seasons/2022/week2.txt
# ./seasons/2022/week3.txt
# ./seasons/2022/week4.txt
# ./seasons/2022/week5.txt
# ./seasons/2022/week6.txt
# ./seasons/2022/week7.txt
# ./seasons/2022/week8.txt
# ./seasons/2022/week9.txt
# ./seasons/2022/week10.txt
# ./seasons/2022/week11.txt
# ./seasons/2022/week12.txt
# ./seasons/2022/week13.txt
# ./seasons/2022/week14.txt
# ./seasons/2022/week15.txt
# ./seasons/2022/week16.txt
# ./seasons/2022/week17.txt
# ./seasons/2023/week1.txt
# ./seasons/2023/week2.txt
# ./seasons/2023/week3.txt
# ./seasons/2023/week4.txt
# ./seasons/2023/week5.txt
# ./seasons/2023/week6.txt
# ./seasons/2023/week7.txt
# ./seasons/2023/week8.txt
# ./seasons/2023/week9.txt
# ./seasons/2023/week10.txt
# ./seasons/2023/week11.txt
# ./seasons/2023/week12.txt
# ./seasons/2023/week13.txt
# ./seasons/2023/week14.txt
# ./seasons/2023/week15.txt
# ./seasons/2023/week16.txt
# ./seasons/2023/week17.txt
# ./seasons/2024/week1.txt
# ./seasons/2024/week2.txt
# ./seasons/2024/week3.txt
# ./seasons/2024/week4.txt
# ./seasons/2024/week5.txt
# ./seasons/2024/week6.txt
# ./seasons/2024/week7.txt
# ./seasons/2024/week8.txt
# ./seasons/2024/week9.txt
# ./seasons/2024/week10.txt
# ./seasons/2024/week11.txt
# ./seasons/2024/week12.txt
# ./seasons/2024/week13.txt
# ./seasons/2024/week14.txt
# ./seasons/2024/week15.txt
# ./seasons/2024/week16.txt
# ./seasons/2024/week17.txt
#       year  week        team  points  estimated points manager
# 0     2015     1  BALLZ DEEP  128.94            103.77       ?
# 1     2015     2  BALLZ DEEP  112.54            107.53       ?
# 2     2015     3  BALLZ DEEP   91.90             98.70       ?
# 3     2015     4  BALLZ DEEP   89.68            110.94       ?
# 4     2015     5  BALLZ DEEP  116.82             92.21       ?
# ...    ...   ...         ...     ...               ...     ...
# 1803  2024    13  Shmo Stars  111.02            123.88    Zach
# 1804  2024    14  Shmo Stars  117.42            118.81    Zach
# 1805  2024    15  Shmo Stars  134.00            124.06    Zach
# 1806  2024    16  Shmo Stars  148.04            126.63    Zach
# 1807  2024    17  Shmo Stars  115.40            114.86    Zach
#
# [1808 rows x 6 columns]

# %%
def process_standings(filename):
    print(filename)

    year = Path(filename).parent.name

    data = []
    with open(filename, 'r') as file_in:
        for line in file_in.readlines():
            split_line = line.strip().split()
            if split_line[1] == 'logo':
                split_line.remove('logo')
            data.append(split_line)

    processed_data = []
    for i, line in enumerate(data):
        if i == 0:
            new_line = line[0:2] + [line[2]] + [' '.join(line[3:5])] + [' '.join(line[5:7])] + line[-3:]
            processed_data.append(new_line)
        else:
            stop = 0
            for j, item in enumerate(line):
                if len(item.split('-')) > 2:
                    stop = j
            new_line = [line[0]] + [' '.join(line[1:stop])] + line[stop:]
            processed_data.append(new_line)

    processed_data[0].append('Clinched Playoffs')

    final_data = []
    for i, line in enumerate(processed_data):
        if '*' in line[0]:
            line[0] = line[0].replace('*', '')
            line.append('Y')
        elif i > 0:
            line.append('N')
        final_data.append(line)
    
    df = pd.DataFrame(final_data[1:], columns=final_data[0])

    df['Year'] = year
    df[['W','L', 'T']] = df['W-L-T'].str.split('-', expand=True)
    df['Moves'] = df['Moves'].replace('-', 0)

    convert_to_int = ['Rank', 'W', 'L', 'T', 'Waiver', 'Moves']
    for i in convert_to_int:
        df[i] = df[i].astype(int)
    
    convert_to_float = ['Pts For', 'Pts Agnst']
    for i in convert_to_float:
        df[i] = df[i].astype(float)

    df.drop(['W-L-T'], axis=1, inplace=True)

    df = df.rename(columns={
        'Rank': 'rank',
        'Team': 'team',
        'Pts For': 'points for',
        'Pts Agnst': 'points against',
        'Streak': 'streak',
        'Waiver': 'waiver',
        'Moves': 'moves',
        'Clinched Playoffs': 'clinched playoffs',
        'Year': 'year',
        'W': 'wins',
        'L': 'losses',
        'T': 'ties'
    })

    df = df[[
        'year', 
        'rank', 
        'team', 
        'wins', 
        'losses', 
        'ties', 
        'points for', 
        'points against', 
        'clinched playoffs', 
        # 'streak',
        'waiver', 
        'moves'
        ]]
    
    df['year'] = df['year'].astype(int)

    return df

standings_files = natural_sort(glob.glob('./seasons/*/standings.txt'))

frames = [process_standings(filename) for filename in standings_files]

df_standings = pd.concat(frames)
df_standings = df_standings.merge(df_managers, on=['team', 'year'])
df_standings = df_standings.sort_values(by=['year', 'rank'], ascending=[True, True])
df_standings
# Out:
# ./seasons/2014/standings.txt
# ./seasons/2015/standings.txt
# ./seasons/2016/standings.txt
# ./seasons/2017/standings.txt
# ./seasons/2018/standings.txt
# ./seasons/2019/standings.txt
# ./seasons/2020/standings.txt
# ./seasons/2021/standings.txt
# ./seasons/2022/standings.txt
# ./seasons/2023/standings.txt
# ./seasons/2024/standings.txt
#      year  rank              team  wins  losses  ties  points for  \
# 0    2014     1        Shmo Stars     9       4     0     1739.14
# 1    2014     2  Officer Friendly     8       5     0     1726.60
# 2    2014     3     Down Set Smut    10       3     0     1870.04
# 3    2014     4      mollywhoppin     9       4     0     1854.68
# 4    2014     5    AK shine squad     7       6     0     1597.66
# ..    ...   ...               ...   ...     ...   ...         ...
# 107  2024     6   Natural Athlete     8       6     0     1677.28
# 108  2024     7        Head Coach     6       8     0     1709.26
# 109  2024     8     Mollywhoppers     6       8     0     1757.16
# 110  2024     9    Trash sandwich     6       8     0     1690.86
# 111  2024    10        Shmo Stars     5       9     0     1745.02
#
#      points against clinched playoffs  waiver  moves manager
# 0           1628.26                 Y       9     20    Zach
# 1           1618.60                 Y      10     17    Masi
# 2           1556.32                 Y       4     12   Ciggy
# 3           1666.06                 Y       8     17    Stew
# 4           1612.82                 Y       7     22      AK
# ..              ...               ...     ...    ...     ...
# 107         1756.82                 Y       4     27    Burg
# 108         1639.86                 N       3     32   Ciggy
# 109         1783.24                 N       8     29    Stew
# 110         1731.92                 N       1     11    Jake
# 111         1897.12                 N       7     15    Zach
#
# [112 rows x 12 columns]

# %% [markdown]
# # Statistics

# %% [markdown]
# ## Number of seasons in the league

# %%
df_seasons_played = df_standings['manager'].value_counts().to_frame(name='total seasons').reset_index()
df_seasons_played
# Out:
#    manager  total seasons
# 0     Zach             11
# 1     Masi             11
# 2    Ciggy             11
# 3     Stew             11
# 4       AK             11
# 5     Burg             11
# 6    Marsh             11
# 7     Moni             11
# 8     Jake              7
# 9    Shoey              7
# 10     Het              4
# 11    Kyle              3
# 12    Phil              1
# 13       ?              1
# 14    Dane              1

# %% [markdown]
# ## Average rank

# %%
df_average_rank = df_standings.groupby('manager')['rank'].mean().to_frame().reset_index()
df_average_rank['rank'] = round(df_average_rank['rank'], 2)
df_average_rank
# Out:
#    manager   rank
# 0        ?  12.00
# 1       AK   5.27
# 2     Burg   5.82
# 3    Ciggy   7.36
# 4     Dane  10.00
# 5      Het   9.25
# 6     Jake   5.43
# 7     Kyle   4.00
# 8    Marsh   4.36
# 9     Masi   2.91
# 10    Moni   5.27
# 11    Phil   8.00
# 12   Shoey   4.71
# 13    Stew   6.36
# 14    Zach   6.09

# %% [markdown]
# ## Most top 3 finishes

# %%
df_top_three = df_standings[df_standings['rank'] <= 3]
df_top_three = df_top_three.groupby(['manager', 'rank']).size().unstack(fill_value=0).reset_index()
df_top_three = df_top_three.rename(columns={1: 'first', 2: 'second', 3: 'third'})
df_top_three['total'] = df_top_three['first'] + df_top_three['second'] + df_top_three['third']
df_top_three = df_top_three.merge(df_seasons_played, on='manager')
df_top_three['profit'] = (df_top_three['first'] * 600 + df_top_three['second']
                          * 300 + df_top_three['third'] * 100) - (df_top_three['total seasons'] * 100)
df_top_three
# Out:
#    manager  first  second  third  total  total seasons  profit
# 0       AK      0       4      0      4             11     100
# 1     Burg      1       0      2      3             11    -300
# 2    Ciggy      0       0      1      1             11   -1000
# 3     Jake      2       0      0      2              7     500
# 4     Kyle      0       1      0      1              3       0
# 5    Marsh      2       0      3      5             11     400
# 6     Masi      3       3      2      8             11    1800
# 7     Moni      2       1      0      3             11     400
# 8    Shoey      0       1      2      3              7    -200
# 9     Stew      0       0      1      1             11   -1000
# 10    Zach      1       1      0      2             11    -200

# %% [markdown]
# ## Most playoff appearances

# %%
df_clinched_playoffs = df_standings[df_standings['clinched playoffs'] == 'Y']
df_clinched_playoffs = df_clinched_playoffs.groupby('manager').size().reset_index()
df_clinched_playoffs = df_clinched_playoffs.rename(columns={0: 'count'})
df_clinched_playoffs = df_clinched_playoffs.merge(df_seasons_played, on='manager')
df_clinched_playoffs['percentage'] = round(df_clinched_playoffs['count'] / df_clinched_playoffs['total seasons'] * 100, 1)
df_clinched_playoffs
# Out:
#    manager  count  total seasons  percentage
# 0       AK      7             11        63.6
# 1     Burg      7             11        63.6
# 2    Ciggy      3             11        27.3
# 3     Jake      4              7        57.1
# 4     Kyle      3              3       100.0
# 5    Marsh      9             11        81.8
# 6     Masi     10             11        90.9
# 7     Moni      7             11        63.6
# 8    Shoey      5              7        71.4
# 9     Stew      5             11        45.5
# 10    Zach      6             11        54.5

# %% [markdown]
# ## Highest points for season total

# %%
df_pts_total_season_high = df_standings.loc[df_standings.groupby('manager')['points for'].idxmax()]
df_pts_total_season_high = df_pts_total_season_high[['year', 'rank', 'manager', 'points for']]
df_pts_total_season_high
# Out:
#      year  rank manager  points for
# 21   2015    12       ?     1450.74
# 93   2023     2      AK     1901.92
# 85   2022     4    Burg     1829.92
# 2    2014     3   Ciggy     1870.04
# 31   2016    10    Dane      429.84
# 20   2015    11     Het     1602.22
# 52   2019     1    Jake     1720.46
# 13   2015     4    Kyle     1563.28
# 44   2018     3   Marsh     1962.32
# 82   2022     1    Masi     2030.34
# 103  2024     2    Moni     1848.54
# 17   2015     8    Phil     1624.20
# 45   2018     4   Shoey     2015.86
# 3    2014     4    Stew     1854.68
# 46   2018     5    Zach     1815.26

# %% [markdown]
# ## Highest weekly score

# %%
df_weekly_high_score = df_weekly.loc[df_weekly.groupby('manager')['points'].idxmax()]
df_weekly_high_score
# Out:
#       year  week                  team  points  estimated points manager
# 5     2015     6            BALLZ DEEP  150.14            107.14       ?
# 76    2017    15      Handy Man Kanaan  188.00            130.75      AK
# 301   2020    16        CeeDeezNutsAsh  184.62            136.57    Burg
# 382   2014    14         Down Set Smut  198.20            146.36   Ciggy
# 548   2016     1            Arken rens  134.38            130.42    Dane
# 580   2015     1          Chew...PILL!  177.94            128.24     Het
# 657   2019    15               My team  192.02            129.67    Jake
# 760   2015     5           kyle's Team  161.34            103.92    Kyle
# 860   2018    11  The Environmentalist  204.22            146.48   Marsh
# 1013  2016    16      Officer Friendly  208.48            132.15    Masi
# 1203  2017    11     JenLuckMeLongTime  197.58            142.04    Moni
# 1330  2015     8      New Kens Russian  167.82            128.86    Phil
# 1346  2018     8       Golden Rams Fam  199.56            151.24   Shoey
# 1549  2020     2          mollywhoppin  194.10            130.58    Stew
# 1661  2015    15            Shmo Stars  254.80            136.46    Zach

# %% [markdown]
# ## Lowest weekly score

# %%
df_weekly_low_score = df_weekly.loc[df_weekly.groupby('manager')['points'].idxmin()]
df_weekly_low_score
# Out:
#       year  week                  team  points  estimated points manager
# 3     2015     4            BALLZ DEEP   89.68            110.94       ?
# 146   2022     5   Waiver Wire Wieners   63.04            122.46      AK
# 317   2021    16  Burg’sHugeDitkaInAsh   49.14             97.45    Burg
# 400   2015    16         Down Set Smut   54.74             91.13   Ciggy
# 552   2016     5            Arken rens    0.00              0.00    Dane
# 608   2016    14        SWOLE Team Six   67.40            121.80     Het
# 711   2023     5        Trash sandwich   61.22            105.13    Jake
# 752   2014    12           WE DEM BOYZ   62.50            101.29    Kyle
# 921   2022     7            Your Coach   70.90            128.99   Marsh
# 971   2014     6      Officer Friendly   68.88            134.19    Masi
# 1187  2016    11   JenLikeDeezBeforeTs   61.28            119.10    Moni
# 1329  2015     7      New Kens Russian   74.60             98.23    Phil
# 1366  2019    12       Golden Rams Fam   67.32            107.75   Shoey
# 1525  2018     9          mollywhoppin   70.76            107.39    Stew
# 1787  2023    14            Shmo Stars   67.20            127.99    Zach

# %% [markdown]
# # Save files

# %%
final = {}

final['weekly'] = df_weekly.to_dict(orient='records')
final['standings'] = df_standings.to_dict(orient='records')

final['statistics'] = {
    'average_rank': df_average_rank.to_dict(orient='records'),
    'top_three_finishes': df_top_three.to_dict(orient='records'),
    'playoff_appearances': df_clinched_playoffs.to_dict(orient='records'),
    'highest_season_total': df_pts_total_season_high.to_dict(orient='records'),
    'highest_weekly_total': df_weekly_high_score.to_dict(orient='records'),
    'lowest_weekly_total': df_weekly_low_score.to_dict(orient='records')
}

with open("../src/data/data.json", "w") as fp:
    json.dump(final, fp, indent=2)

final
# Out:
# {'weekly': [{'year': 2015,
#    'week': 1,
#    'team': 'BALLZ DEEP',
#    'points': 128.94,
#    'estimated points': 103.77,
#    'manager': '?'},
#   {'year': 2015,
#    'week': 2,
#    'team': 'BALLZ DEEP',
#    'points': 112.54,
#    'estimated points': 107.53,
#    'manager': '?'},
#   {'year': 2015,
#    'week': 3,
#    'team': 'BALLZ DEEP',
#    'points': 91.9,
#    'estimated points': 98.7,
#    'manager': '?'},
#   {'year': 2015,
#    'week': 4,
#    'team': 'BALLZ DEEP',
#    'points': 89.68,
#    'estimated points': 110.94,
#    'manager': '?'},
#   {'year': 2015,
#    'week': 5,
#    'team': 'BALLZ DEEP',
#    'points': 116.82,
#    'estimated points': 92.21,
#    'manager': '?'},
#   {'year': 2015,
#    'week': 6,
#    'team': 'BALLZ DEEP',
#    'points': 150.14,
#    'estimated points': 107.14,
#    'manager': '?'},
#   {'year': 2015,
#    'week': 7,
#    'team': 'BALLZ DEEP',
#    'points': 110.4,
#    'estimated points': 117.58,
#    'manager': '?'},
#   {'year': 2015,
#    'week': 8,
#    'team': 'BALLZ DEEP',
#    'points': 101.2,
#    'estimated points': 100.67,
#    'manager': '?'},
#   {'year': 2015,
#    'week': 9,
#    'team': 'BALLZ DEEP',
#    'points': 93.96,
#    'estimated points': 89.49,
#    'manager': '?'},
#   {'year': 2015,
#    'week': 10,
#    'team': 'BALLZ DEEP',
#    'points': 104.8,
#    'estimated points': 118.46,
#    'manager': '?'},
#   {'year': 2015,
#    'week': 11,
#    'team': 'BALLZ DEEP',
#    'points': 129.7,
#    'estimated points': 127.02,
#    'manager': '?'},
#   {'year': 2015,
#    'week': 12,
#    'team': 'BALLZ DEEP',
#    'points': 111.7,
#    'estimated points': 123.42,
#    'manager': '?'},
#   {'year': 2015,
#    'week': 13,
#    'team': 'BALLZ DEEP',
#    'points': 108.96,
#    'estimated points': 114.13,
#    'manager': '?'},
#   {'year': 2015,
#    'week': 14,
#    'team': 'BALLZ DEEP',
#    'points': 113.28,
#    'estimated points': 109.37,
#    'manager': '?'},
#   {'year': 2015,
#    'week': 15,
#    'team': 'BALLZ DEEP',
#    'points': 132.66,
#    'estimated points': 119.9,
#    'manager': '?'},
#   {'year': 2014,
#    'week': 1,
#    'team': 'AK shine squad',
#    'points': 103.82,
#    'estimated points': 131.69,
#    'manager': 'AK'},
#   {'year': 2014,
#    'week': 2,
#    'team': 'AK shine squad',
#    'points': 126.76,
#    'estimated points': 121.82,
#    'manager': 'AK'},
#   {'year': 2014,
#    'week': 3,
#    'team': 'AK shine squad',
#    'points': 114.94,
#    'estimated points': 126.47,
#    'manager': 'AK'},
#   {'year': 2014,
#    'week': 4,
#    'team': 'AK shine squad',
#    'points': 123.88,
#    'estimated points': 117.07,
#    'manager': 'AK'},
#   {'year': 2014,
#    'week': 5,
#    'team': 'AK shine squad',
#    'points': 134.12,
#    'estimated points': 125.2,
#    'manager': 'AK'},
#   {'year': 2014,
#    'week': 6,
#    'team': 'AK shine squad',
#    'points': 119.52,
#    'estimated points': 123.94,
#    'manager': 'AK'},
#   {'year': 2014,
#    'week': 7,
#    'team': 'AK shine squad',
#    'points': 160.02,
#    'estimated points': 126.23,
#    'manager': 'AK'},
#   {'year': 2014,
#    'week': 8,
#    'team': 'AK shine squad',
#    'points': 137.38,
#    'estimated points': 140.1,
#    'manager': 'AK'},
#   {'year': 2014,
#    'week': 9,
#    'team': 'AK shine squad',
#    'points': 92.02,
#    'estimated points': 141.34,
#    'manager': 'AK'},
#   {'year': 2014,
#    'week': 10,
#    'team': 'AK shine squad',
#    'points': 111.46,
#    'estimated points': 110.82,
#    'manager': 'AK'},
#   {'year': 2014,
#    'week': 11,
#    'team': 'AK shine squad',
#    'points': 89.32,
#    'estimated points': 116.32,
#    'manager': 'AK'},
#   {'year': 2014,
#    'week': 12,
#    'team': 'AK shine squad',
#    'points': 122.92,
#    'estimated points': 130.26,
#    'manager': 'AK'},
#   {'year': 2014,
#    'week': 13,
#    'team': 'AK shine squad',
#    'points': 161.5,
#    'estimated points': 133.26,
#    'manager': 'AK'},
#   {'year': 2014,
#    'week': 14,
#    'team': 'AK shine squad',
#    'points': 104.06,
#    'estimated points': 134.46,
#    'manager': 'AK'},
#   {'year': 2014,
#    'week': 15,
#    'team': 'AK shine squad',
#    'points': 114.74,
#    'estimated points': 114.94,
#    'manager': 'AK'},
#   {'year': 2015,
#    'week': 1,
#    'team': 'Handy Man Kanaan',
#    'points': 123.1,
#    'estimated points': 120.74,
#    'manager': 'AK'},
#   {'year': 2015,
#    'week': 2,
#    'team': 'Handy Man Kanaan',
#    'points': 125.7,
#    'estimated points': 122.96,
#    'manager': 'AK'},
#   {'year': 2015,
#    'week': 3,
#    'team': 'Handy Man Kanaan',
#    'points': 143.18,
#    'estimated points': 115.59,
#    'manager': 'AK'},
#   {'year': 2015,
#    'week': 4,
#    'team': 'Handy Man Kanaan',
#    'points': 121.66,
#    'estimated points': 120.68,
#    'manager': 'AK'},
#   {'year': 2015,
#    'week': 5,
#    'team': 'Handy Man Kanaan',
#    'points': 140.8,
#    'estimated points': 103.95,
#    'manager': 'AK'},
#   {'year': 2015,
#    'week': 6,
#    'team': 'Handy Man Kanaan',
#    'points': 117.58,
#    'estimated points': 119.45,
#    'manager': 'AK'},
#   {'year': 2015,
#    'week': 7,
#    'team': 'Handy Man Kanaan',
#    'points': 122.8,
#    'estimated points': 117.26,
#    'manager': 'AK'},
#   {'year': 2015,
#    'week': 8,
#    'team': 'Handy Man Kanaan',
#    'points': 122.76,
#    'estimated points': 126.29,
#    'manager': 'AK'},
#   {'year': 2015,
#    'week': 9,
#    'team': 'Handy Man Kanaan',
#    'points': 153.24,
#    'estimated points': 126.48,
#    'manager': 'AK'},
#   {'year': 2015,
#    'week': 10,
#    'team': 'Handy Man Kanaan',
#    'points': 152.36,
#    'estimated points': 129.71,
#    'manager': 'AK'},
#   {'year': 2015,
#    'week': 11,
#    'team': 'Handy Man Kanaan',
#    'points': 88.66,
#    'estimated points': 119.83,
#    'manager': 'AK'},
#   {'year': 2015,
#    'week': 12,
#    'team': 'Handy Man Kanaan',
#    'points': 121.32,
#    'estimated points': 129.91,
#    'manager': 'AK'},
#   {'year': 2015,
#    'week': 13,
#    'team': 'Handy Man Kanaan',
#    'points': 148.48,
#    'estimated points': 134.73,
#    'manager': 'AK'},
#   {'year': 2015,
#    'week': 14,
#    'team': 'Handy Man Kanaan',
#    'points': 133.18,
#    'estimated points': 131.91,
#    'manager': 'AK'},
#   {'year': 2015,
#    'week': 15,
#    'team': 'Handy Man Kanaan',
#    'points': 138.74,
#    'estimated points': 126.66,
#    'manager': 'AK'},
#   {'year': 2015,
#    'week': 16,
#    'team': 'Handy Man Kanaan',
#    'points': 119.4,
#    'estimated points': 129.28,
#    'manager': 'AK'},
#   {'year': 2016,
#    'week': 1,
#    'team': 'Handy Man Kanaan',
#    'points': 136.92,
#    'estimated points': 129.2,
#    'manager': 'AK'},
#   {'year': 2016,
#    'week': 2,
#    'team': 'Handy Man Kanaan',
#    'points': 109.52,
#    'estimated points': 123.69,
#    'manager': 'AK'},
#   {'year': 2016,
#    'week': 3,
#    'team': 'Handy Man Kanaan',
#    'points': 145.14,
#    'estimated points': 130.41,
#    'manager': 'AK'},
#   {'year': 2016,
#    'week': 4,
#    'team': 'Handy Man Kanaan',
#    'points': 162.38,
#    'estimated points': 133.82,
#    'manager': 'AK'},
#   {'year': 2016,
#    'week': 5,
#    'team': 'Handy Man Kanaan',
#    'points': 129.56,
#    'estimated points': 138.9,
#    'manager': 'AK'},
#   {'year': 2016,
#    'week': 6,
#    'team': 'Handy Man Kanaan',
#    'points': 124.3,
#    'estimated points': 142.68,
#    'manager': 'AK'},
#   {'year': 2016,
#    'week': 7,
#    'team': 'Handy Man Kanaan',
#    'points': 135.78,
#    'estimated points': 131.16,
#    'manager': 'AK'},
#   {'year': 2016,
#    'week': 8,
#    'team': 'Handy Man Kanaan',
#    'points': 115.8,
#    'estimated points': 127.98,
#    'manager': 'AK'},
#   {'year': 2016,
#    'week': 9,
#    'team': 'Handy Man Kanaan',
#    'points': 124.42,
#    'estimated points': 140.77,
#    'manager': 'AK'},
#   {'year': 2016,
#    'week': 10,
#    'team': 'Handy Man Kanaan',
#    'points': 157.02,
#    'estimated points': 120.63,
#    'manager': 'AK'},
#   {'year': 2016,
#    'week': 11,
#    'team': 'Handy Man Kanaan',
#    'points': 118.1,
#    'estimated points': 132.29,
#    'manager': 'AK'},
#   {'year': 2016,
#    'week': 12,
#    'team': 'Handy Man Kanaan',
#    'points': 140.7,
#    'estimated points': 133.08,
#    'manager': 'AK'},
#   {'year': 2016,
#    'week': 13,
#    'team': 'Handy Man Kanaan',
#    'points': 122.04,
#    'estimated points': 119.28,
#    'manager': 'AK'},
#   {'year': 2016,
#    'week': 14,
#    'team': 'Handy Man Kanaan',
#    'points': 102.18,
#    'estimated points': 131.26,
#    'manager': 'AK'},
#   {'year': 2016,
#    'week': 15,
#    'team': 'Handy Man Kanaan',
#    'points': 150.46,
#    'estimated points': 128.16,
#    'manager': 'AK'},
#   {'year': 2016,
#    'week': 16,
#    'team': 'Handy Man Kanaan',
#    'points': 133.36,
#    'estimated points': 135.91,
#    'manager': 'AK'},
#   {'year': 2017,
#    'week': 1,
#    'team': 'Handy Man Kanaan',
#    'points': 118.02,
#    'estimated points': 126.29,
#    'manager': 'AK'},
#   {'year': 2017,
#    'week': 2,
#    'team': 'Handy Man Kanaan',
#    'points': 153.12,
#    'estimated points': 132.7,
#    'manager': 'AK'},
#   {'year': 2017,
#    'week': 3,
#    'team': 'Handy Man Kanaan',
#    'points': 166.9,
#    'estimated points': 130.09,
#    'manager': 'AK'},
#   {'year': 2017,
#    'week': 4,
#    'team': 'Handy Man Kanaan',
#    'points': 124.54,
#    'estimated points': 135.86,
#    'manager': 'AK'},
#   {'year': 2017,
#    'week': 5,
#    'team': 'Handy Man Kanaan',
#    'points': 119.48,
#    'estimated points': 134.01,
#    'manager': 'AK'},
#   {'year': 2017,
#    'week': 6,
#    'team': 'Handy Man Kanaan',
#    'points': 166.74,
#    'estimated points': 131.64,
#    'manager': 'AK'},
#   {'year': 2017,
#    'week': 7,
#    'team': 'Handy Man Kanaan',
#    'points': 116.78,
#    'estimated points': 131.75,
#    'manager': 'AK'},
#   {'year': 2017,
#    'week': 8,
#    'team': 'Handy Man Kanaan',
#    'points': 104.48,
#    'estimated points': 114.75,
#    'manager': 'AK'},
#   {'year': 2017,
#    'week': 9,
#    'team': 'Handy Man Kanaan',
#    'points': 101.82,
#    'estimated points': 113.77,
#    'manager': 'AK'},
#   {'year': 2017,
#    'week': 10,
#    'team': 'Handy Man Kanaan',
#    'points': 113.02,
#    'estimated points': 109.33,
#    'manager': 'AK'},
#   {'year': 2017,
#    'week': 11,
#    'team': 'Handy Man Kanaan',
#    'points': 102.0,
#    'estimated points': 126.44,
#    'manager': 'AK'},
#   {'year': 2017,
#    'week': 12,
#    'team': 'Handy Man Kanaan',
#    'points': 104.66,
#    'estimated points': 130.8,
#    'manager': 'AK'},
#   {'year': 2017,
#    'week': 13,
#    'team': 'Handy Man Kanaan',
#    'points': 95.58,
#    'estimated points': 121.18,
#    'manager': 'AK'},
#   {'year': 2017,
#    'week': 14,
#    'team': 'Handy Man Kanaan',
#    'points': 126.82,
#    'estimated points': 125.2,
#    'manager': 'AK'},
#   {'year': 2017,
#    'week': 15,
#    'team': 'Handy Man Kanaan',
#    'points': 188.0,
#    'estimated points': 130.75,
#    'manager': 'AK'},
#   {'year': 2018,
#    'week': 1,
#    'team': 'Handy Man Kanaan',
#    'points': 179.88,
#    'estimated points': 132.01,
#    'manager': 'AK'},
#   {'year': 2018,
#    'week': 2,
#    'team': 'Handy Man Kanaan',
#    'points': 134.78,
#    'estimated points': 127.35,
#    'manager': 'AK'},
#   {'year': 2018,
#    'week': 3,
#    'team': 'Handy Man Kanaan',
#    'points': 113.12,
#    'estimated points': 133.04,
#    'manager': 'AK'},
#   {'year': 2018,
#    'week': 4,
#    'team': 'Handy Man Kanaan',
#    'points': 150.86,
#    'estimated points': 132.37,
#    'manager': 'AK'},
#   {'year': 2018,
#    'week': 5,
#    'team': 'Handy Man Kanaan',
#    'points': 145.44,
#    'estimated points': 131.78,
#    'manager': 'AK'},
#   {'year': 2018,
#    'week': 6,
#    'team': 'Handy Man Kanaan',
#    'points': 151.0,
#    'estimated points': 138.31,
#    'manager': 'AK'},
#   {'year': 2018,
#    'week': 7,
#    'team': 'Handy Man Kanaan',
#    'points': 141.28,
#    'estimated points': 135.2,
#    'manager': 'AK'},
#   {'year': 2018,
#    'week': 8,
#    'team': 'Handy Man Kanaan',
#    'points': 98.56,
#    'estimated points': 135.52,
#    'manager': 'AK'},
#   {'year': 2018,
#    'week': 9,
#    'team': 'Handy Man Kanaan',
#    'points': 146.16,
#    'estimated points': 145.37,
#    'manager': 'AK'},
#   {'year': 2018,
#    'week': 10,
#    'team': 'Handy Man Kanaan',
#    'points': 146.46,
#    'estimated points': 134.89,
#    'manager': 'AK'},
#   {'year': 2018,
#    'week': 11,
#    'team': 'Handy Man Kanaan',
#    'points': 143.98,
#    'estimated points': 140.34,
#    'manager': 'AK'},
#   {'year': 2018,
#    'week': 12,
#    'team': 'Handy Man Kanaan',
#    'points': 108.72,
#    'estimated points': 132.75,
#    'manager': 'AK'},
#   {'year': 2018,
#    'week': 13,
#    'team': 'Handy Man Kanaan',
#    'points': 97.44,
#    'estimated points': 137.98,
#    'manager': 'AK'},
#   {'year': 2018,
#    'week': 14,
#    'team': 'Handy Man Kanaan',
#    'points': 134.32,
#    'estimated points': 134.54,
#    'manager': 'AK'},
#   {'year': 2018,
#    'week': 15,
#    'team': 'Handy Man Kanaan',
#    'points': 92.66,
#    'estimated points': 140.77,
#    'manager': 'AK'},
#   {'year': 2018,
#    'week': 16,
#    'team': 'Handy Man Kanaan',
#    'points': 124.14,
#    'estimated points': 134.46,
#    'manager': 'AK'},
#   {'year': 2019,
#    'week': 1,
#    'team': 'Handy Man Kanaan',
#    'points': 90.84,
#    'estimated points': 132.69,
#    'manager': 'AK'},
#   {'year': 2019,
#    'week': 2,
#    'team': 'Handy Man Kanaan',
#    'points': 130.46,
#    'estimated points': 135.45,
#    'manager': 'AK'},
#   {'year': 2019,
#    'week': 3,
#    'team': 'Handy Man Kanaan',
#    'points': 121.14,
#    'estimated points': 138.1,
#    'manager': 'AK'},
#   {'year': 2019,
#    'week': 4,
#    'team': 'Handy Man Kanaan',
#    'points': 101.52,
#    'estimated points': 133.22,
#    'manager': 'AK'},
#   {'year': 2019,
#    'week': 5,
#    'team': 'Handy Man Kanaan',
#    'points': 171.92,
#    'estimated points': 120.19,
#    'manager': 'AK'},
#   {'year': 2019,
#    'week': 6,
#    'team': 'Handy Man Kanaan',
#    'points': 93.22,
#    'estimated points': 128.97,
#    'manager': 'AK'},
#   {'year': 2019,
#    'week': 7,
#    'team': 'Handy Man Kanaan',
#    'points': 89.06,
#    'estimated points': 125.38,
#    'manager': 'AK'},
#   {'year': 2019,
#    'week': 8,
#    'team': 'Handy Man Kanaan',
#    'points': 160.88,
#    'estimated points': 120.49,
#    'manager': 'AK'},
#   {'year': 2019,
#    'week': 9,
#    'team': 'Handy Man Kanaan',
#    'points': 100.18,
#    'estimated points': 124.3,
#    'manager': 'AK'},
#   {'year': 2019,
#    'week': 10,
#    'team': 'Handy Man Kanaan',
#    'points': 142.28,
#    'estimated points': 121.34,
#    'manager': 'AK'},
#   {'year': 2019,
#    'week': 11,
#    'team': 'Handy Man Kanaan',
#    'points': 109.46,
#    'estimated points': 119.74,
#    'manager': 'AK'},
#   {'year': 2019,
#    'week': 12,
#    'team': 'Handy Man Kanaan',
#    'points': 68.98,
#    'estimated points': 102.27,
#    'manager': 'AK'},
#   {'year': 2019,
#    'week': 13,
#    'team': 'Handy Man Kanaan',
#    'points': 86.2,
#    'estimated points': 121.1,
#    'manager': 'AK'},
#   {'year': 2019,
#    'week': 14,
#    'team': 'Handy Man Kanaan',
#    'points': 96.46,
#    'estimated points': 110.35,
#    'manager': 'AK'},
#   {'year': 2019,
#    'week': 15,
#    'team': 'Handy Man Kanaan',
#    'points': 102.28,
#    'estimated points': 100.35,
#    'manager': 'AK'},
#   {'year': 2019,
#    'week': 16,
#    'team': 'Handy Man Kanaan',
#    'points': 115.2,
#    'estimated points': 105.58,
#    'manager': 'AK'},
#   {'year': 2020,
#    'week': 1,
#    'team': 'Handy Man Kanaan',
#    'points': 103.26,
#    'estimated points': 133.72,
#    'manager': 'AK'},
#   {'year': 2020,
#    'week': 2,
#    'team': 'Handy Man Kanaan',
#    'points': 116.18,
#    'estimated points': 131.45,
#    'manager': 'AK'},
#   {'year': 2020,
#    'week': 3,
#    'team': 'Handy Man Kanaan',
#    'points': 110.58,
#    'estimated points': 123.54,
#    'manager': 'AK'},
#   {'year': 2020,
#    'week': 4,
#    'team': 'Handy Man Kanaan',
#    'points': 164.5,
#    'estimated points': 128.11,
#    'manager': 'AK'},
#   {'year': 2020,
#    'week': 5,
#    'team': 'Handy Man Kanaan',
#    'points': 95.22,
#    'estimated points': 130.96,
#    'manager': 'AK'},
#   {'year': 2020,
#    'week': 6,
#    'team': 'Handy Man Kanaan',
#    'points': 110.74,
#    'estimated points': 134.3,
#    'manager': 'AK'},
#   {'year': 2020,
#    'week': 7,
#    'team': 'Handy Man Kanaan',
#    'points': 142.36,
#    'estimated points': 128.52,
#    'manager': 'AK'},
#   {'year': 2020,
#    'week': 8,
#    'team': 'Handy Man Kanaan',
#    'points': 115.46,
#    'estimated points': 128.29,
#    'manager': 'AK'},
#   {'year': 2020,
#    'week': 9,
#    'team': 'Handy Man Kanaan',
#    'points': 80.36,
#    'estimated points': 115.91,
#    'manager': 'AK'},
#   {'year': 2020,
#    'week': 10,
#    'team': 'Handy Man Kanaan',
#    'points': 116.64,
#    'estimated points': 112.33,
#    'manager': 'AK'},
#   {'year': 2020,
#    'week': 11,
#    'team': 'Handy Man Kanaan',
#    'points': 129.84,
#    'estimated points': 119.04,
#    'manager': 'AK'},
#   {'year': 2020,
#    'week': 12,
#    'team': 'Handy Man Kanaan',
#    'points': 150.5,
#    'estimated points': 122.46,
#    'manager': 'AK'},
#   {'year': 2020,
#    'week': 13,
#    'team': 'Handy Man Kanaan',
#    'points': 113.9,
#    'estimated points': 123.94,
#    'manager': 'AK'},
#   {'year': 2020,
#    'week': 14,
#    'team': 'Handy Man Kanaan',
#    'points': 130.64,
#    'estimated points': 121.03,
#    'manager': 'AK'},
#   {'year': 2020,
#    'week': 15,
#    'team': 'Handy Man Kanaan',
#    'points': 122.8,
#    'estimated points': 122.68,
#    'manager': 'AK'},
#   {'year': 2020,
#    'week': 16,
#    'team': 'Handy Man Kanaan',
#    'points': 128.82,
#    'estimated points': 127.64,
#    'manager': 'AK'},
#   {'year': 2021,
#    'week': 1,
#    'team': 'Handy Man Kanaan',
#    'points': 124.96,
#    'estimated points': 146.58,
#    'manager': 'AK'},
#   {'year': 2021,
#    'week': 2,
#    'team': 'Handy Man Kanaan',
#    'points': 134.22,
#    'estimated points': 144.26,
#    'manager': 'AK'},
#   {'year': 2021,
#    'week': 3,
#    'team': 'Handy Man Kanaan',
#    'points': 101.92,
#    'estimated points': 132.42,
#    'manager': 'AK'},
#   {'year': 2021,
#    'week': 4,
#    'team': 'Handy Man Kanaan',
#    'points': 104.36,
#    'estimated points': 133.04,
#    'manager': 'AK'},
#   {'year': 2021,
#    'week': 5,
#    'team': 'Handy Man Kanaan',
#    'points': 139.28,
#    'estimated points': 137.02,
#    'manager': 'AK'},
#   {'year': 2021,
#    'week': 6,
#    'team': 'Handy Man Kanaan',
#    'points': 143.42,
#    'estimated points': 139.65,
#    'manager': 'AK'},
#   {'year': 2021,
#    'week': 7,
#    'team': 'Handy Man Kanaan',
#    'points': 143.04,
#    'estimated points': 118.24,
#    'manager': 'AK'},
#   {'year': 2021,
#    'week': 8,
#    'team': 'Handy Man Kanaan',
#    'points': 105.14,
#    'estimated points': 137.71,
#    'manager': 'AK'},
#   {'year': 2021,
#    'week': 9,
#    'team': 'Handy Man Kanaan',
#    'points': 108.4,
#    'estimated points': 138.59,
#    'manager': 'AK'},
#   {'year': 2021,
#    'week': 10,
#    'team': 'Handy Man Kanaan',
#    'points': 67.24,
#    'estimated points': 143.3,
#    'manager': 'AK'},
#   {'year': 2021,
#    'week': 11,
#    'team': 'Handy Man Kanaan',
#    'points': 136.18,
#    'estimated points': 136.23,
#    'manager': 'AK'},
#   {'year': 2021,
#    'week': 12,
#    'team': 'Handy Man Kanaan',
#    'points': 129.38,
#    'estimated points': 132.64,
#    'manager': 'AK'},
#   {'year': 2021,
#    'week': 13,
#    'team': 'Handy Man Kanaan',
#    'points': 138.1,
#    'estimated points': 133.57,
#    'manager': 'AK'},
#   {'year': 2021,
#    'week': 14,
#    'team': 'Handy Man Kanaan',
#    'points': 124.1,
#    'estimated points': 132.85,
#    'manager': 'AK'},
#   {'year': 2021,
#    'week': 15,
#    'team': 'Handy Man Kanaan',
#    'points': 81.08,
#    'estimated points': 134.75,
#    'manager': 'AK'},
#   {'year': 2021,
#    'week': 16,
#    'team': 'Handy Man Kanaan',
#    'points': 147.54,
#    'estimated points': 123.72,
#    'manager': 'AK'},
#   {'year': 2021,
#    'week': 17,
#    'team': 'Handy Man Kanaan',
#    'points': 155.84,
#    'estimated points': 141.49,
#    'manager': 'AK'},
#   {'year': 2022,
#    'week': 1,
#    'team': 'Waiver Wire Wieners',
#    'points': 101.58,
#    'estimated points': 131.45,
#    'manager': 'AK'},
#   {'year': 2022,
#    'week': 2,
#    'team': 'Waiver Wire Wieners',
#    'points': 131.4,
#    'estimated points': 129.85,
#    'manager': 'AK'},
#   {'year': 2022,
#    'week': 3,
#    'team': 'Waiver Wire Wieners',
#    'points': 69.74,
#    'estimated points': 119.52,
#    'manager': 'AK'},
#   {'year': 2022,
#    'week': 4,
#    'team': 'Waiver Wire Wieners',
#    'points': 136.9,
#    'estimated points': 121.12,
#    'manager': 'AK'},
#   {'year': 2022,
#    'week': 5,
#    'team': 'Waiver Wire Wieners',
#    'points': 63.04,
#    'estimated points': 122.46,
#    'manager': 'AK'},
#   {'year': 2022,
#    'week': 6,
#    'team': 'Waiver Wire Wieners',
#    'points': 72.76,
#    'estimated points': 109.34,
#    'manager': 'AK'},
#   {'year': 2022,
#    'week': 7,
#    'team': 'Waiver Wire Wieners',
#    'points': 89.9,
#    'estimated points': 114.27,
#    'manager': 'AK'},
#   {'year': 2022,
#    'week': 8,
#    'team': 'Waiver Wire Wieners',
#    'points': 145.88,
#    'estimated points': 117.89,
#    'manager': 'AK'},
#   {'year': 2022,
#    'week': 9,
#    'team': 'Waiver Wire Wieners',
#    'points': 97.5,
#    'estimated points': 119.38,
#    'manager': 'AK'},
#   {'year': 2022,
#    'week': 10,
#    'team': 'Waiver Wire Wieners',
#    'points': 92.78,
#    'estimated points': 108.88,
#    'manager': 'AK'},
#   {'year': 2022,
#    'week': 11,
#    'team': 'Waiver Wire Wieners',
#    'points': 90.1,
#    'estimated points': 108.69,
#    'manager': 'AK'},
#   {'year': 2022,
#    'week': 12,
#    'team': 'Waiver Wire Wieners',
#    'points': 130.56,
#    'estimated points': 112.25,
#    'manager': 'AK'},
#   {'year': 2022,
#    'week': 13,
#    'team': 'Waiver Wire Wieners',
#    'points': 99.92,
#    'estimated points': 114.48,
#    'manager': 'AK'},
#   {'year': 2022,
#    'week': 14,
#    'team': 'Waiver Wire Wieners',
#    'points': 100.0,
#    'estimated points': 119.24,
#    'manager': 'AK'},
#   {'year': 2022,
#    'week': 15,
#    'team': 'Waiver Wire Wieners',
#    'points': 135.7,
#    'estimated points': 115.64,
#    'manager': 'AK'},
#   {'year': 2022,
#    'week': 16,
#    'team': 'Waiver Wire Wieners',
#    'points': 126.26,
#    'estimated points': 115.67,
#    'manager': 'AK'},
#   {'year': 2022,
#    'week': 17,
#    'team': 'Waiver Wire Wieners',
#    'points': 96.3,
#    'estimated points': 118.18,
#    'manager': 'AK'},
#   {'year': 2023,
#    'week': 1,
#    'team': 'Wieners UpRising',
#    'points': 94.2,
#    'estimated points': 115.42,
#    'manager': 'AK'},
#   {'year': 2023,
#    'week': 2,
#    'team': 'Wieners UpRising',
#    'points': 118.42,
#    'estimated points': 111.56,
#    'manager': 'AK'},
#   {'year': 2023,
#    'week': 3,
#    'team': 'Wieners UpRising',
#    'points': 160.68,
#    'estimated points': 114.09,
#    'manager': 'AK'},
#   {'year': 2023,
#    'week': 4,
#    'team': 'Wieners UpRising',
#    'points': 176.56,
#    'estimated points': 120.22,
#    'manager': 'AK'},
#   {'year': 2023,
#    'week': 5,
#    'team': 'Wieners UpRising',
#    'points': 172.12,
#    'estimated points': 127.02,
#    'manager': 'AK'},
#   {'year': 2023,
#    'week': 6,
#    'team': 'Wieners UpRising',
#    'points': 154.5,
#    'estimated points': 135.44,
#    'manager': 'AK'},
#   {'year': 2023,
#    'week': 7,
#    'team': 'Wieners UpRising',
#    'points': 125.76,
#    'estimated points': 129.19,
#    'manager': 'AK'},
#   {'year': 2023,
#    'week': 8,
#    'team': 'Wieners UpRising',
#    'points': 154.36,
#    'estimated points': 132.34,
#    'manager': 'AK'},
#   {'year': 2023,
#    'week': 9,
#    'team': 'Wieners UpRising',
#    'points': 150.78,
#    'estimated points': 119.28,
#    'manager': 'AK'},
#   {'year': 2023,
#    'week': 10,
#    'team': 'Wieners UpRising',
#    'points': 83.14,
#    'estimated points': 108.05,
#    'manager': 'AK'},
#   {'year': 2023,
#    'week': 11,
#    'team': 'Wieners UpRising',
#    'points': 90.7,
#    'estimated points': 134.82,
#    'manager': 'AK'},
#   {'year': 2023,
#    'week': 12,
#    'team': 'Wieners UpRising',
#    'points': 125.3,
#    'estimated points': 130.49,
#    'manager': 'AK'},
#   {'year': 2023,
#    'week': 13,
#    'team': 'Wieners UpRising',
#    'points': 171.02,
#    'estimated points': 120.48,
#    'manager': 'AK'},
#   {'year': 2023,
#    'week': 14,
#    'team': 'Wieners UpRising',
#    'points': 124.38,
#    'estimated points': 124.21,
#    'manager': 'AK'},
#   {'year': 2023,
#    'week': 15,
#    'team': 'Wieners UpRising',
#    'points': 117.92,
#    'estimated points': 129.36,
#    'manager': 'AK'},
#   {'year': 2023,
#    'week': 16,
#    'team': 'Wieners UpRising',
#    'points': 110.64,
#    'estimated points': 128.56,
#    'manager': 'AK'},
#   {'year': 2023,
#    'week': 17,
#    'team': 'Wieners UpRising',
#    'points': 114.18,
#    'estimated points': 133.5,
#    'manager': 'AK'},
#   {'year': 2024,
#    'week': 1,
#    'team': 'Wieners UpRising',
#    'points': 105.72,
#    'estimated points': 118.76,
#    'manager': 'AK'},
#   {'year': 2024,
#    'week': 2,
#    'team': 'Wieners UpRising',
#    'points': 157.6,
#    'estimated points': 117.93,
#    'manager': 'AK'},
#   {'year': 2024,
#    'week': 3,
#    'team': 'Wieners UpRising',
#    'points': 113.32,
#    'estimated points': 115.03,
#    'manager': 'AK'},
#   {'year': 2024,
#    'week': 4,
#    'team': 'Wieners UpRising',
#    'points': 139.8,
#    'estimated points': 118.6,
#    'manager': 'AK'},
#   {'year': 2024,
#    'week': 5,
#    'team': 'Wieners UpRising',
#    'points': 117.06,
#    'estimated points': 122.82,
#    'manager': 'AK'},
#   {'year': 2024,
#    'week': 6,
#    'team': 'Wieners UpRising',
#    'points': 120.98,
#    'estimated points': 101.11,
#    'manager': 'AK'},
#   {'year': 2024,
#    'week': 7,
#    'team': 'Wieners UpRising',
#    'points': 102.6,
#    'estimated points': 113.56,
#    'manager': 'AK'},
#   {'year': 2024,
#    'week': 8,
#    'team': 'Wieners UpRising',
#    'points': 107.74,
#    'estimated points': 113.61,
#    'manager': 'AK'},
#   {'year': 2024,
#    'week': 9,
#    'team': 'Wieners UpRising',
#    'points': 89.8,
#    'estimated points': 104.98,
#    'manager': 'AK'},
#   {'year': 2024,
#    'week': 10,
#    'team': 'Wieners UpRising',
#    'points': 90.04,
#    'estimated points': 103.77,
#    'manager': 'AK'},
#   {'year': 2024,
#    'week': 11,
#    'team': 'Wieners UpRising',
#    'points': 96.1,
#    'estimated points': 120.9,
#    'manager': 'AK'},
#   {'year': 2024,
#    'week': 12,
#    'team': 'Wieners UpRising',
#    'points': 107.26,
#    'estimated points': 128.34,
#    'manager': 'AK'},
#   {'year': 2024,
#    'week': 13,
#    'team': 'Wieners UpRising',
#    'points': 130.4,
#    'estimated points': 125.16,
#    'manager': 'AK'},
#   {'year': 2024,
#    'week': 14,
#    'team': 'Wieners UpRising',
#    'points': 146.74,
#    'estimated points': 113.63,
#    'manager': 'AK'},
#   {'year': 2024,
#    'week': 15,
#    'team': 'Wieners UpRising',
#    'points': 109.44,
#    'estimated points': 123.22,
#    'manager': 'AK'},
#   {'year': 2024,
#    'week': 16,
#    'team': 'Wieners UpRising',
#    'points': 142.92,
#    'estimated points': 123.77,
#    'manager': 'AK'},
#   {'year': 2014,
#    'week': 1,
#    'team': "Ashley's Pouncey",
#    'points': 151.68,
#    'estimated points': 126.11,
#    'manager': 'Burg'},
#   {'year': 2014,
#    'week': 2,
#    'team': "Ashley's Pouncey",
#    'points': 137.26,
#    'estimated points': 132.83,
#    'manager': 'Burg'},
#   {'year': 2014,
#    'week': 3,
#    'team': "Ashley's Pouncey",
#    'points': 103.56,
#    'estimated points': 130.21,
#    'manager': 'Burg'},
#   {'year': 2014,
#    'week': 4,
#    'team': "Ashley's Pouncey",
#    'points': 123.36,
#    'estimated points': 122.09,
#    'manager': 'Burg'},
#   {'year': 2014,
#    'week': 5,
#    'team': "Ashley's Pouncey",
#    'points': 92.5,
#    'estimated points': 136.18,
#    'manager': 'Burg'},
#   {'year': 2014,
#    'week': 6,
#    'team': "Ashley's Pouncey",
#    'points': 129.74,
#    'estimated points': 116.87,
#    'manager': 'Burg'},
#   {'year': 2014,
#    'week': 7,
#    'team': "Ashley's Pouncey",
#    'points': 100.64,
#    'estimated points': 106.6,
#    'manager': 'Burg'},
#   {'year': 2014,
#    'week': 8,
#    'team': "Ashley's Pouncey",
#    'points': 176.66,
#    'estimated points': 136.52,
#    'manager': 'Burg'},
#   {'year': 2014,
#    'week': 9,
#    'team': "Ashley's Pouncey",
#    'points': 137.12,
#    'estimated points': 127.77,
#    'manager': 'Burg'},
#   {'year': 2014,
#    'week': 10,
#    'team': "Ashley's Pouncey",
#    'points': 133.52,
#    'estimated points': 121.26,
#    'manager': 'Burg'},
#   {'year': 2014,
#    'week': 11,
#    'team': "Ashley's Pouncey",
#    'points': 118.08,
#    'estimated points': 132.97,
#    'manager': 'Burg'},
#   {'year': 2014,
#    'week': 12,
#    'team': "Ashley's Pouncey",
#    'points': 108.66,
#    'estimated points': 129.27,
#    'manager': 'Burg'},
#   {'year': 2014,
#    'week': 13,
#    'team': "Ashley's Pouncey",
#    'points': 91.8,
#    'estimated points': 136.98,
#    'manager': 'Burg'},
#   {'year': 2014,
#    'week': 14,
#    'team': "Ashley's Pouncey",
#    'points': 111.88,
#    'estimated points': 138.19,
#    'manager': 'Burg'},
#   {'year': 2014,
#    'week': 15,
#    'team': "Ashley's Pouncey",
#    'points': 149.38,
#    'estimated points': 127.08,
#    'manager': 'Burg'},
#   {'year': 2014,
#    'week': 16,
#    'team': "Ashley's Pouncey",
#    'points': 148.88,
#    'estimated points': 131.1,
#    'manager': 'Burg'},
#   {'year': 2015,
#    'week': 1,
#    'team': 'AshleysTDs&Pouncey',
#    'points': 77.8,
#    'estimated points': 123.1,
#    'manager': 'Burg'},
#   {'year': 2015,
#    'week': 2,
#    'team': 'AshleysTDs&Pouncey',
#    'points': 118.18,
#    'estimated points': 120.2,
#    'manager': 'Burg'},
#   {'year': 2015,
#    'week': 3,
#    'team': 'AshleysTDs&Pouncey',
#    'points': 173.38,
#    'estimated points': 132.08,
#    'manager': 'Burg'},
#   {'year': 2015,
#    'week': 4,
#    'team': 'AshleysTDs&Pouncey',
#    'points': 101.64,
#    'estimated points': 119.38,
#    'manager': 'Burg'},
#   {'year': 2015,
#    'week': 5,
#    'team': 'AshleysTDs&Pouncey',
#    'points': 77.34,
#    'estimated points': 107.33,
#    'manager': 'Burg'},
#   {'year': 2015,
#    'week': 6,
#    'team': 'AshleysTDs&Pouncey',
#    'points': 127.18,
#    'estimated points': 123.23,
#    'manager': 'Burg'},
#   {'year': 2015,
#    'week': 7,
#    'team': 'AshleysTDs&Pouncey',
#    'points': 87.54,
#    'estimated points': 118.94,
#    'manager': 'Burg'},
#   {'year': 2015,
#    'week': 8,
#    'team': 'AshleysTDs&Pouncey',
#    'points': 143.8,
#    'estimated points': 126.39,
#    'manager': 'Burg'},
#   {'year': 2015,
#    'week': 9,
#    'team': 'AshleysTDs&Pouncey',
#    'points': 146.8,
#    'estimated points': 120.52,
#    'manager': 'Burg'},
#   {'year': 2015,
#    'week': 10,
#    'team': 'AshleysTDs&Pouncey',
#    'points': 130.82,
#    'estimated points': 122.4,
#    'manager': 'Burg'},
#   {'year': 2015,
#    'week': 11,
#    'team': 'AshleysTDs&Pouncey',
#    'points': 109.68,
#    'estimated points': 135.33,
#    'manager': 'Burg'},
#   {'year': 2015,
#    'week': 12,
#    'team': 'AshleysTDs&Pouncey',
#    'points': 160.64,
#    'estimated points': 130.81,
#    'manager': 'Burg'},
#   {'year': 2015,
#    'week': 13,
#    'team': 'AshleysTDs&Pouncey',
#    'points': 146.48,
#    'estimated points': 135.19,
#    'manager': 'Burg'},
#   {'year': 2015,
#    'week': 14,
#    'team': 'AshleysTDs&Pouncey',
#    'points': 141.7,
#    'estimated points': 134.65,
#    'manager': 'Burg'},
#   {'year': 2015,
#    'week': 15,
#    'team': 'AshleysTDs&Pouncey',
#    'points': 120.94,
#    'estimated points': 130.1,
#    'manager': 'Burg'},
#   {'year': 2015,
#    'week': 16,
#    'team': 'AshleysTDs&Pouncey',
#    'points': 139.0,
#    'estimated points': 129.04,
#    'manager': 'Burg'},
#   {'year': 2016,
#    'week': 1,
#    'team': 'AshleyGivesWoodHead',
#    'points': 124.64,
#    'estimated points': 118.43,
#    'manager': 'Burg'},
#   {'year': 2016,
#    'week': 2,
#    'team': 'AshleyGivesWoodHead',
#    'points': 148.16,
#    'estimated points': 120.96,
#    'manager': 'Burg'},
#   {'year': 2016,
#    'week': 3,
#    'team': 'AshleyGivesWoodHead',
#    'points': 121.48,
#    'estimated points': 124.29,
#    'manager': 'Burg'},
#   {'year': 2016,
#    'week': 4,
#    'team': 'AshleyGivesWoodHead',
#    'points': 140.52,
#    'estimated points': 130.04,
#    'manager': 'Burg'},
#   {'year': 2016,
#    'week': 5,
#    'team': 'AshleyGivesWoodHead',
#    'points': 115.2,
#    'estimated points': 126.06,
#    'manager': 'Burg'},
#   {'year': 2016,
#    'week': 6,
#    'team': 'AshleyGivesWoodHead',
#    'points': 141.66,
#    'estimated points': 116.57,
#    'manager': 'Burg'},
#   {'year': 2016,
#    'week': 7,
#    'team': 'AshleyGivesWoodHead',
#    'points': 142.14,
#    'estimated points': 117.26,
#    'manager': 'Burg'},
#   {'year': 2016,
#    'week': 8,
#    'team': 'AshleyGivesWoodHead',
#    'points': 123.12,
#    'estimated points': 121.0,
#    'manager': 'Burg'},
#   {'year': 2016,
#    'week': 9,
#    'team': 'AshleyGivesWoodHead',
#    'points': 141.58,
#    'estimated points': 110.21,
#    'manager': 'Burg'},
#   {'year': 2016,
#    'week': 10,
#    'team': 'AshleyGivesWoodHead',
#    'points': 106.74,
#    'estimated points': 126.11,
#    'manager': 'Burg'},
#   {'year': 2016,
#    'week': 11,
#    'team': 'AshleyGivesWoodHead',
#    'points': 126.82,
#    'estimated points': 105.51,
#    'manager': 'Burg'},
#   {'year': 2016,
#    'week': 12,
#    'team': 'AshleyGivesWoodHead',
#    'points': 170.66,
#    'estimated points': 125.26,
#    'manager': 'Burg'},
#   {'year': 2016,
#    'week': 13,
#    'team': 'AshleyGivesWoodHead',
#    'points': 147.4,
#    'estimated points': 129.11,
#    'manager': 'Burg'},
#   {'year': 2016,
#    'week': 14,
#    'team': 'AshleyGivesWoodHead',
#    'points': 75.5,
#    'estimated points': 113.06,
#    'manager': 'Burg'},
#   {'year': 2016,
#    'week': 15,
#    'team': 'AshleyGivesWoodHead',
#    'points': 105.6,
#    'estimated points': 121.12,
#    'manager': 'Burg'},
#   {'year': 2016,
#    'week': 16,
#    'team': 'AshleyGivesWoodHead',
#    'points': 134.3,
#    'estimated points': 121.31,
#    'manager': 'Burg'},
#   {'year': 2017,
#    'week': 1,
#    'team': "BmyL on Ashley'sTD's",
#    'points': 94.54,
#    'estimated points': 115.66,
#    'manager': 'Burg'},
#   {'year': 2017,
#    'week': 2,
#    'team': "BmyL on Ashley'sTD's",
#    'points': 103.22,
#    'estimated points': 124.14,
#    'manager': 'Burg'},
#   {'year': 2017,
#    'week': 3,
#    'team': "BmyL on Ashley'sTD's",
#    'points': 140.18,
#    'estimated points': 127.42,
#    'manager': 'Burg'},
#   {'year': 2017,
#    'week': 4,
#    'team': "BmyL on Ashley'sTD's",
#    'points': 94.38,
#    'estimated points': 134.5,
#    'manager': 'Burg'},
#   {'year': 2017,
#    'week': 5,
#    'team': "BmyL on Ashley'sTD's",
#    'points': 127.6,
#    'estimated points': 127.9,
#    'manager': 'Burg'},
#   {'year': 2017,
#    'week': 6,
#    'team': "BmyL on Ashley'sTD's",
#    'points': 124.16,
#    'estimated points': 121.02,
#    'manager': 'Burg'},
#   {'year': 2017,
#    'week': 7,
#    'team': "BmyL on Ashley'sTD's",
#    'points': 67.44,
#    'estimated points': 125.4,
#    'manager': 'Burg'},
#   {'year': 2017,
#    'week': 8,
#    'team': "BmyL on Ashley'sTD's",
#    'points': 139.04,
#    'estimated points': 126.68,
#    'manager': 'Burg'},
#   {'year': 2017,
#    'week': 9,
#    'team': "BmyL on Ashley'sTD's",
#    'points': 95.86,
#    'estimated points': 117.7,
#    'manager': 'Burg'},
#   {'year': 2017,
#    'week': 10,
#    'team': "BmyL on Ashley'sTD's",
#    'points': 98.96,
#    'estimated points': 111.91,
#    'manager': 'Burg'},
#   {'year': 2017,
#    'week': 11,
#    'team': "BmyL on Ashley'sTD's",
#    'points': 119.42,
#    'estimated points': 121.93,
#    'manager': 'Burg'},
#   {'year': 2017,
#    'week': 12,
#    'team': "BmyL on Ashley'sTD's",
#    'points': 135.08,
#    'estimated points': 119.69,
#    'manager': 'Burg'},
#   {'year': 2017,
#    'week': 13,
#    'team': "BmyL on Ashley'sTD's",
#    'points': 93.82,
#    'estimated points': 124.27,
#    'manager': 'Burg'},
#   {'year': 2017,
#    'week': 14,
#    'team': "BmyL on Ashley'sTD's",
#    'points': 132.94,
#    'estimated points': 105.84,
#    'manager': 'Burg'},
#   {'year': 2017,
#    'week': 15,
#    'team': "BmyL on Ashley'sTD's",
#    'points': 109.28,
#    'estimated points': 118.34,
#    'manager': 'Burg'},
#   {'year': 2017,
#    'week': 16,
#    'team': "BmyL on Ashley'sTD's",
#    'points': 78.5,
#    'estimated points': 108.56,
#    'manager': 'Burg'},
#   {'year': 2018,
#    'week': 1,
#    'team': 'Ray’s Burger’s',
#    'points': 107.42,
#    'estimated points': 134.91,
#    'manager': 'Burg'},
#   {'year': 2018,
#    'week': 2,
#    'team': 'Ray’s Burger’s',
#    'points': 123.02,
#    'estimated points': 132.82,
#    'manager': 'Burg'},
#   {'year': 2018,
#    'week': 3,
#    'team': 'Ray’s Burger’s',
#    'points': 127.76,
#    'estimated points': 142.51,
#    'manager': 'Burg'},
#   {'year': 2018,
#    'week': 4,
#    'team': 'Ray’s Burger’s',
#    'points': 130.06,
#    'estimated points': 139.88,
#    'manager': 'Burg'},
#   {'year': 2018,
#    'week': 5,
#    'team': 'Ray’s Burger’s',
#    'points': 119.22,
#    'estimated points': 132.36,
#    'manager': 'Burg'},
#   {'year': 2018,
#    'week': 6,
#    'team': 'Ray’s Burger’s',
#    'points': 175.78,
#    'estimated points': 148.43,
#    'manager': 'Burg'},
#   {'year': 2018,
#    'week': 7,
#    'team': 'Ray’s Burger’s',
#    'points': 171.44,
#    'estimated points': 139.42,
#    'manager': 'Burg'},
#   {'year': 2018,
#    'week': 8,
#    'team': 'Ray’s Burger’s',
#    'points': 129.82,
#    'estimated points': 146.7,
#    'manager': 'Burg'},
#   {'year': 2018,
#    'week': 9,
#    'team': 'Ray’s Burger’s',
#    'points': 122.1,
#    'estimated points': 129.63,
#    'manager': 'Burg'},
#   {'year': 2018,
#    'week': 10,
#    'team': 'Ray’s Burger’s',
#    'points': 132.46,
#    'estimated points': 142.89,
#    'manager': 'Burg'},
#   {'year': 2018,
#    'week': 11,
#    'team': 'Ray’s Burger’s',
#    'points': 101.32,
#    'estimated points': 140.4,
#    'manager': 'Burg'},
#   {'year': 2018,
#    'week': 12,
#    'team': 'Ray’s Burger’s',
#    'points': 153.4,
#    'estimated points': 127.32,
#    'manager': 'Burg'},
#   {'year': 2018,
#    'week': 13,
#    'team': 'Ray’s Burger’s',
#    'points': 144.7,
#    'estimated points': 150.41,
#    'manager': 'Burg'},
#   {'year': 2018,
#    'week': 14,
#    'team': 'Ray’s Burger’s',
#    'points': 112.98,
#    'estimated points': 138.53,
#    'manager': 'Burg'},
#   {'year': 2018,
#    'week': 15,
#    'team': 'Ray’s Burger’s',
#    'points': 102.62,
#    'estimated points': 136.21,
#    'manager': 'Burg'},
#   {'year': 2019,
#    'week': 1,
#    'team': 'BurgsChubbInAshley',
#    'points': 156.9,
#    'estimated points': 135.41,
#    'manager': 'Burg'},
#   {'year': 2019,
#    'week': 2,
#    'team': 'BurgsChubbInAshley',
#    'points': 94.22,
#    'estimated points': 134.45,
#    'manager': 'Burg'},
#   {'year': 2019,
#    'week': 3,
#    'team': 'BurgsChubbInAshley',
#    'points': 116.84,
#    'estimated points': 135.86,
#    'manager': 'Burg'},
#   {'year': 2019,
#    'week': 4,
#    'team': 'BurgsChubbInAshley',
#    'points': 105.7,
#    'estimated points': 121.77,
#    'manager': 'Burg'},
#   {'year': 2019,
#    'week': 5,
#    'team': 'BurgsChubbInAshley',
#    'points': 143.72,
#    'estimated points': 126.46,
#    'manager': 'Burg'},
#   {'year': 2019,
#    'week': 6,
#    'team': 'BurgsChubbInAshley',
#    'points': 91.06,
#    'estimated points': 136.14,
#    'manager': 'Burg'},
#   {'year': 2019,
#    'week': 7,
#    'team': 'BurgsChubbInAshley',
#    'points': 122.76,
#    'estimated points': 125.59,
#    'manager': 'Burg'},
#   {'year': 2019,
#    'week': 8,
#    'team': 'BurgsChubbInAshley',
#    'points': 97.06,
#    'estimated points': 116.51,
#    'manager': 'Burg'},
#   {'year': 2019,
#    'week': 9,
#    'team': 'BurgsChubbInAshley',
#    'points': 120.7,
#    'estimated points': 129.63,
#    'manager': 'Burg'},
#   {'year': 2019,
#    'week': 10,
#    'team': 'BurgsChubbInAshley',
#    'points': 155.28,
#    'estimated points': 130.8,
#    'manager': 'Burg'},
#   {'year': 2019,
#    'week': 11,
#    'team': 'BurgsChubbInAshley',
#    'points': 115.42,
#    'estimated points': 115.91,
#    'manager': 'Burg'},
#   {'year': 2019,
#    'week': 12,
#    'team': 'BurgsChubbInAshley',
#    'points': 138.84,
#    'estimated points': 129.48,
#    'manager': 'Burg'},
#   {'year': 2019,
#    'week': 13,
#    'team': 'BurgsChubbInAshley',
#    'points': 103.66,
#    'estimated points': 136.31,
#    'manager': 'Burg'},
#   {'year': 2019,
#    'week': 14,
#    'team': 'BurgsChubbInAshley',
#    'points': 131.76,
#    'estimated points': 133.03,
#    'manager': 'Burg'},
#   {'year': 2019,
#    'week': 15,
#    'team': 'BurgsChubbInAshley',
#    'points': 83.32,
#    'estimated points': 134.26,
#    'manager': 'Burg'},
#   {'year': 2020,
#    'week': 1,
#    'team': 'CeeDeezNutsAsh',
#    'points': 106.8,
#    'estimated points': 132.04,
#    'manager': 'Burg'},
#   {'year': 2020,
#    'week': 2,
#    'team': 'CeeDeezNutsAsh',
#    'points': 182.68,
#    'estimated points': 135.52,
#    'manager': 'Burg'},
#   {'year': 2020,
#    'week': 3,
#    'team': 'CeeDeezNutsAsh',
#    'points': 147.34,
#    'estimated points': 140.42,
#    'manager': 'Burg'},
#   {'year': 2020,
#    'week': 4,
#    'team': 'CeeDeezNutsAsh',
#    'points': 154.5,
#    'estimated points': 138.99,
#    'manager': 'Burg'},
#   {'year': 2020,
#    'week': 5,
#    'team': 'CeeDeezNutsAsh',
#    'points': 146.58,
#    'estimated points': 141.69,
#    'manager': 'Burg'},
#   {'year': 2020,
#    'week': 6,
#    'team': 'CeeDeezNutsAsh',
#    'points': 92.32,
#    'estimated points': 131.01,
#    'manager': 'Burg'},
#   {'year': 2020,
#    'week': 7,
#    'team': 'CeeDeezNutsAsh',
#    'points': 104.1,
#    'estimated points': 124.41,
#    'manager': 'Burg'},
#   {'year': 2020,
#    'week': 8,
#    'team': 'CeeDeezNutsAsh',
#    'points': 102.6,
#    'estimated points': 118.96,
#    'manager': 'Burg'},
#   {'year': 2020,
#    'week': 9,
#    'team': 'CeeDeezNutsAsh',
#    'points': 118.94,
#    'estimated points': 128.46,
#    'manager': 'Burg'},
#   {'year': 2020,
#    'week': 10,
#    'team': 'CeeDeezNutsAsh',
#    'points': 150.88,
#    'estimated points': 141.05,
#    'manager': 'Burg'},
#   {'year': 2020,
#    'week': 11,
#    'team': 'CeeDeezNutsAsh',
#    'points': 132.34,
#    'estimated points': 139.11,
#    'manager': 'Burg'},
#   {'year': 2020,
#    'week': 12,
#    'team': 'CeeDeezNutsAsh',
#    'points': 83.94,
#    'estimated points': 131.21,
#    'manager': 'Burg'},
#   {'year': 2020,
#    'week': 13,
#    'team': 'CeeDeezNutsAsh',
#    'points': 123.84,
#    'estimated points': 125.23,
#    'manager': 'Burg'},
#   {'year': 2020,
#    'week': 14,
#    'team': 'CeeDeezNutsAsh',
#    'points': 145.98,
#    'estimated points': 123.06,
#    'manager': 'Burg'},
#   {'year': 2020,
#    'week': 15,
#    'team': 'CeeDeezNutsAsh',
#    'points': 136.96,
#    'estimated points': 136.67,
#    'manager': 'Burg'},
#   {'year': 2020,
#    'week': 16,
#    'team': 'CeeDeezNutsAsh',
#    'points': 184.62,
#    'estimated points': 136.57,
#    'manager': 'Burg'},
#   {'year': 2021,
#    'week': 1,
#    'team': 'Burg’sHugeDitkaInAsh',
#    'points': 137.28,
#    'estimated points': 137.12,
#    'manager': 'Burg'},
#   {'year': 2021,
#    'week': 2,
#    'team': 'Burg’sHugeDitkaInAsh',
#    'points': 106.02,
#    'estimated points': 144.52,
#    'manager': 'Burg'},
#   {'year': 2021,
#    'week': 3,
#    'team': 'Burg’sHugeDitkaInAsh',
#    'points': 126.04,
#    'estimated points': 146.73,
#    'manager': 'Burg'},
#   {'year': 2021,
#    'week': 4,
#    'team': 'Burg’sHugeDitkaInAsh',
#    'points': 101.38,
#    'estimated points': 148.98,
#    'manager': 'Burg'},
#   {'year': 2021,
#    'week': 5,
#    'team': 'Burg’sHugeDitkaInAsh',
#    'points': 175.12,
#    'estimated points': 141.68,
#    'manager': 'Burg'},
#   {'year': 2021,
#    'week': 6,
#    'team': 'Burg’sHugeDitkaInAsh',
#    'points': 147.7,
#    'estimated points': 140.03,
#    'manager': 'Burg'},
#   {'year': 2021,
#    'week': 7,
#    'team': 'Burg’sHugeDitkaInAsh',
#    'points': 84.18,
#    'estimated points': 123.52,
#    'manager': 'Burg'},
#   {'year': 2021,
#    'week': 8,
#    'team': 'Burg’sHugeDitkaInAsh',
#    'points': 72.82,
#    'estimated points': 136.36,
#    'manager': 'Burg'},
#   {'year': 2021,
#    'week': 9,
#    'team': 'Burg’sHugeDitkaInAsh',
#    'points': 108.04,
#    'estimated points': 129.82,
#    'manager': 'Burg'},
#   {'year': 2021,
#    'week': 10,
#    'team': 'Burg’sHugeDitkaInAsh',
#    'points': 144.4,
#    'estimated points': 135.71,
#    'manager': 'Burg'},
#   {'year': 2021,
#    'week': 11,
#    'team': 'Burg’sHugeDitkaInAsh',
#    'points': 135.28,
#    'estimated points': 136.75,
#    'manager': 'Burg'},
#   {'year': 2021,
#    'week': 12,
#    'team': 'Burg’sHugeDitkaInAsh',
#    'points': 83.62,
#    'estimated points': 130.62,
#    'manager': 'Burg'},
#   {'year': 2021,
#    'week': 13,
#    'team': 'Burg’sHugeDitkaInAsh',
#    'points': 121.98,
#    'estimated points': 122.58,
#    'manager': 'Burg'},
#   {'year': 2021,
#    'week': 14,
#    'team': 'Burg’sHugeDitkaInAsh',
#    'points': 127.1,
#    'estimated points': 135.04,
#    'manager': 'Burg'},
#   {'year': 2021,
#    'week': 15,
#    'team': 'Burg’sHugeDitkaInAsh',
#    'points': 116.84,
#    'estimated points': 117.0,
#    'manager': 'Burg'},
#   {'year': 2021,
#    'week': 16,
#    'team': 'Burg’sHugeDitkaInAsh',
#    'points': 49.14,
#    'estimated points': 97.45,
#    'manager': 'Burg'},
#   {'year': 2021,
#    'week': 17,
#    'team': 'Burg’sHugeDitkaInAsh',
#    'points': 125.18,
#    'estimated points': 124.95,
#    'manager': 'Burg'},
#   {'year': 2022,
#    'week': 1,
#    'team': 'Natural Athlete',
#    'points': 116.92,
#    'estimated points': 128.44,
#    'manager': 'Burg'},
#   {'year': 2022,
#    'week': 2,
#    'team': 'Natural Athlete',
#    'points': 107.86,
#    'estimated points': 120.21,
#    'manager': 'Burg'},
#   {'year': 2022,
#    'week': 3,
#    'team': 'Natural Athlete',
#    'points': 117.3,
#    'estimated points': 133.73,
#    'manager': 'Burg'},
#   {'year': 2022,
#    'week': 4,
#    'team': 'Natural Athlete',
#    'points': 121.78,
#    'estimated points': 132.0,
#    'manager': 'Burg'},
#   {'year': 2022,
#    'week': 5,
#    'team': 'Natural Athlete',
#    'points': 102.18,
#    'estimated points': 124.02,
#    'manager': 'Burg'},
#   {'year': 2022,
#    'week': 6,
#    'team': 'Natural Athlete',
#    'points': 156.7,
#    'estimated points': 126.69,
#    'manager': 'Burg'},
#   {'year': 2022,
#    'week': 7,
#    'team': 'Natural Athlete',
#    'points': 147.44,
#    'estimated points': 133.09,
#    'manager': 'Burg'},
#   {'year': 2022,
#    'week': 8,
#    'team': 'Natural Athlete',
#    'points': 166.04,
#    'estimated points': 138.96,
#    'manager': 'Burg'},
#   {'year': 2022,
#    'week': 9,
#    'team': 'Natural Athlete',
#    'points': 106.74,
#    'estimated points': 112.53,
#    'manager': 'Burg'},
#   {'year': 2022,
#    'week': 10,
#    'team': 'Natural Athlete',
#    'points': 129.96,
#    'estimated points': 128.15,
#    'manager': 'Burg'},
#   {'year': 2022,
#    'week': 11,
#    'team': 'Natural Athlete',
#    'points': 148.8,
#    'estimated points': 123.37,
#    'manager': 'Burg'},
#   {'year': 2022,
#    'week': 12,
#    'team': 'Natural Athlete',
#    'points': 121.1,
#    'estimated points': 138.32,
#    'manager': 'Burg'},
#   {'year': 2022,
#    'week': 13,
#    'team': 'Natural Athlete',
#    'points': 182.14,
#    'estimated points': 140.6,
#    'manager': 'Burg'},
#   {'year': 2022,
#    'week': 14,
#    'team': 'Natural Athlete',
#    'points': 104.96,
#    'estimated points': 129.0,
#    'manager': 'Burg'},
#   {'year': 2022,
#    'week': 15,
#    'team': 'Natural Athlete',
#    'points': 140.3,
#    'estimated points': 127.33,
#    'manager': 'Burg'},
#   {'year': 2022,
#    'week': 16,
#    'team': 'Natural Athlete',
#    'points': 122.9,
#    'estimated points': 129.24,
#    'manager': 'Burg'},
#   {'year': 2022,
#    'week': 17,
#    'team': 'Natural Athlete',
#    'points': 96.3,
#    'estimated points': 129.05,
#    'manager': 'Burg'},
#   {'year': 2023,
#    'week': 1,
#    'team': 'Natural Athlete',
#    'points': 79.68,
#    'estimated points': 116.12,
#    'manager': 'Burg'},
#   {'year': 2023,
#    'week': 2,
#    'team': 'Natural Athlete',
#    'points': 126.38,
#    'estimated points': 121.12,
#    'manager': 'Burg'},
#   {'year': 2023,
#    'week': 3,
#    'team': 'Natural Athlete',
#    'points': 114.06,
#    'estimated points': 116.17,
#    'manager': 'Burg'},
#   {'year': 2023,
#    'week': 4,
#    'team': 'Natural Athlete',
#    'points': 60.9,
#    'estimated points': 110.95,
#    'manager': 'Burg'},
#   {'year': 2023,
#    'week': 5,
#    'team': 'Natural Athlete',
#    'points': 114.38,
#    'estimated points': 104.29,
#    'manager': 'Burg'},
#   {'year': 2023,
#    'week': 6,
#    'team': 'Natural Athlete',
#    'points': 109.2,
#    'estimated points': 120.74,
#    'manager': 'Burg'},
#   {'year': 2023,
#    'week': 7,
#    'team': 'Natural Athlete',
#    'points': 62.36,
#    'estimated points': 109.66,
#    'manager': 'Burg'},
#   {'year': 2023,
#    'week': 8,
#    'team': 'Natural Athlete',
#    'points': 122.82,
#    'estimated points': 114.62,
#    'manager': 'Burg'},
#   {'year': 2023,
#    'week': 9,
#    'team': 'Natural Athlete',
#    'points': 94.72,
#    'estimated points': 113.01,
#    'manager': 'Burg'},
#   {'year': 2023,
#    'week': 10,
#    'team': 'Natural Athlete',
#    'points': 153.18,
#    'estimated points': 116.16,
#    'manager': 'Burg'},
#   {'year': 2023,
#    'week': 11,
#    'team': 'Natural Athlete',
#    'points': 109.64,
#    'estimated points': 118.36,
#    'manager': 'Burg'},
#   {'year': 2023,
#    'week': 12,
#    'team': 'Natural Athlete',
#    'points': 156.66,
#    'estimated points': 116.27,
#    'manager': 'Burg'},
#   {'year': 2023,
#    'week': 13,
#    'team': 'Natural Athlete',
#    'points': 111.86,
#    'estimated points': 108.45,
#    'manager': 'Burg'},
#   {'year': 2023,
#    'week': 14,
#    'team': 'Natural Athlete',
#    'points': 99.64,
#    'estimated points': 100.41,
#    'manager': 'Burg'},
#   {'year': 2023,
#    'week': 15,
#    'team': 'Natural Athlete',
#    'points': 103.54,
#    'estimated points': 109.04,
#    'manager': 'Burg'},
#   {'year': 2023,
#    'week': 16,
#    'team': 'Natural Athlete',
#    'points': 123.9,
#    'estimated points': 106.6,
#    'manager': 'Burg'},
#   {'year': 2023,
#    'week': 17,
#    'team': 'Natural Athlete',
#    'points': 125.92,
#    'estimated points': 111.7,
# ...
#    'clinched playoffs': 'N',
#    'waiver': 1,
#    'moves': 17,
#    'manager': 'Burg'},
#   {'year': 2021,
#    'rank': 10,
#    'team': 'Route 28 Speed Walkers',
#    'wins': 6,
#    'losses': 8,
#    'ties': 0,
#    'points for': 1646.68,
#    'points against': 1786.18,
#    'clinched playoffs': 'N',
#    'waiver': 3,
#    'moves': 29,
#    'manager': 'Ciggy'},
#   {'year': 2022,
#    'rank': 1,
#    'team': 'Officer Friendly',
#    'wins': 11,
#    'losses': 3,
#    'ties': 0,
#    'points for': 2030.34,
#    'points against': 1678.48,
#    'clinched playoffs': 'Y',
#    'waiver': 9,
#    'moves': 17,
#    'manager': 'Masi'},
#   {'year': 2022,
#    'rank': 2,
#    'team': 'Highlands Hooligan',
#    'wins': 10,
#    'losses': 4,
#    'ties': 0,
#    'points for': 1830.16,
#    'points against': 1650.04,
#    'clinched playoffs': 'Y',
#    'waiver': 10,
#    'moves': 19,
#    'manager': 'Shoey'},
#   {'year': 2022,
#    'rank': 3,
#    'team': 'Your Coach',
#    'wins': 7,
#    'losses': 7,
#    'ties': 0,
#    'points for': 1848.0,
#    'points against': 1708.72,
#    'clinched playoffs': 'Y',
#    'waiver': 4,
#    'moves': 18,
#    'manager': 'Marsh'},
#   {'year': 2022,
#    'rank': 4,
#    'team': 'Natural Athlete',
#    'wins': 8,
#    'losses': 6,
#    'ties': 0,
#    'points for': 1829.92,
#    'points against': 1800.84,
#    'clinched playoffs': 'Y',
#    'waiver': 7,
#    'moves': 25,
#    'manager': 'Burg'},
#   {'year': 2022,
#    'rank': 5,
#    'team': 'Head Coach',
#    'wins': 8,
#    'losses': 6,
#    'ties': 0,
#    'points for': 1767.1,
#    'points against': 1704.2,
#    'clinched playoffs': 'Y',
#    'waiver': 3,
#    'moves': 41,
#    'manager': 'Ciggy'},
#   {'year': 2022,
#    'rank': 6,
#    'team': 'Trash sandwich',
#    'wins': 7,
#    'losses': 7,
#    'ties': 0,
#    'points for': 1691.46,
#    'points against': 1710.3,
#    'clinched playoffs': 'Y',
#    'waiver': 1,
#    'moves': 12,
#    'manager': 'Jake'},
#   {'year': 2022,
#    'rank': 7,
#    'team': 'Burgs downfall',
#    'wins': 5,
#    'losses': 9,
#    'ties': 0,
#    'points for': 1554.0,
#    'points against': 1801.98,
#    'clinched playoffs': 'N',
#    'waiver': 6,
#    'moves': 27,
#    'manager': 'Stew'},
#   {'year': 2022,
#    'rank': 8,
#    'team': 'Waiver Wire Wieners',
#    'wins': 3,
#    'losses': 11,
#    'ties': 0,
#    'points for': 1422.06,
#    'points against': 1768.76,
#    'clinched playoffs': 'N',
#    'waiver': 8,
#    'moves': 38,
#    'manager': 'AK'},
#   {'year': 2022,
#    'rank': 9,
#    'team': 'AngelLikeMoniBoloni',
#    'wins': 5,
#    'losses': 9,
#    'ties': 0,
#    'points for': 1705.6,
#    'points against': 1886.54,
#    'clinched playoffs': 'N',
#    'waiver': 2,
#    'moves': 18,
#    'manager': 'Moni'},
#   {'year': 2022,
#    'rank': 10,
#    'team': 'Out of Timers',
#    'wins': 6,
#    'losses': 8,
#    'ties': 0,
#    'points for': 1597.72,
#    'points against': 1566.5,
#    'clinched playoffs': 'N',
#    'waiver': 5,
#    'moves': 18,
#    'manager': 'Zach'},
#   {'year': 2023,
#    'rank': 1,
#    'team': 'Your Coach',
#    'wins': 7,
#    'losses': 7,
#    'ties': 0,
#    'points for': 1813.24,
#    'points against': 1722.82,
#    'clinched playoffs': 'Y',
#    'waiver': 8,
#    'moves': 21,
#    'manager': 'Marsh'},
#   {'year': 2023,
#    'rank': 2,
#    'team': 'Wieners UpRising',
#    'wins': 7,
#    'losses': 7,
#    'ties': 0,
#    'points for': 1901.92,
#    'points against': 1810.22,
#    'clinched playoffs': 'Y',
#    'waiver': 5,
#    'moves': 16,
#    'manager': 'AK'},
#   {'year': 2023,
#    'rank': 3,
#    'team': 'Officer Friendly',
#    'wins': 10,
#    'losses': 4,
#    'ties': 0,
#    'points for': 1830.02,
#    'points against': 1605.2,
#    'clinched playoffs': 'Y',
#    'waiver': 10,
#    'moves': 17,
#    'manager': 'Masi'},
#   {'year': 2023,
#    'rank': 4,
#    'team': 'Head Coach',
#    'wins': 9,
#    'losses': 5,
#    'ties': 0,
#    'points for': 1825.2,
#    'points against': 1686.56,
#    'clinched playoffs': 'Y',
#    'waiver': 7,
#    'moves': 25,
#    'manager': 'Ciggy'},
#   {'year': 2023,
#    'rank': 5,
#    'team': 'AngelLikeMoniBoloni',
#    'wins': 9,
#    'losses': 5,
#    'ties': 0,
#    'points for': 1693.42,
#    'points against': 1703.98,
#    'clinched playoffs': 'Y',
#    'waiver': 6,
#    'moves': 14,
#    'manager': 'Moni'},
#   {'year': 2023,
#    'rank': 6,
#    'team': 'Auto draft',
#    'wins': 8,
#    'losses': 6,
#    'ties': 0,
#    'points for': 1792.88,
#    'points against': 1803.08,
#    'clinched playoffs': 'Y',
#    'waiver': 1,
#    'moves': 10,
#    'manager': 'Shoey'},
#   {'year': 2023,
#    'rank': 7,
#    'team': 'Trash sandwich',
#    'wins': 4,
#    'losses': 10,
#    'ties': 0,
#    'points for': 1640.22,
#    'points against': 1823.76,
#    'clinched playoffs': 'N',
#    'waiver': 3,
#    'moves': 12,
#    'manager': 'Jake'},
#   {'year': 2023,
#    'rank': 8,
#    'team': 'Mollywhoppers',
#    'wins': 7,
#    'losses': 7,
#    'ties': 0,
#    'points for': 1712.64,
#    'points against': 1819.24,
#    'clinched playoffs': 'N',
#    'waiver': 9,
#    'moves': 27,
#    'manager': 'Stew'},
#   {'year': 2023,
#    'rank': 9,
#    'team': 'Shmo Stars',
#    'wins': 6,
#    'losses': 8,
#    'ties': 0,
#    'points for': 1721.82,
#    'points against': 1719.86,
#    'clinched playoffs': 'N',
#    'waiver': 2,
#    'moves': 23,
#    'manager': 'Zach'},
#   {'year': 2023,
#    'rank': 10,
#    'team': 'Natural Athlete',
#    'wins': 3,
#    'losses': 11,
#    'ties': 0,
#    'points for': 1515.48,
#    'points against': 1752.12,
#    'clinched playoffs': 'N',
#    'waiver': 4,
#    'moves': 25,
#    'manager': 'Burg'},
#   {'year': 2024,
#    'rank': 1,
#    'team': 'Sergeant Friendly',
#    'wins': 7,
#    'losses': 7,
#    'ties': 0,
#    'points for': 1791.12,
#    'points against': 1688.62,
#    'clinched playoffs': 'Y',
#    'waiver': 9,
#    'moves': 16,
#    'manager': 'Masi'},
#   {'year': 2024,
#    'rank': 2,
#    'team': 'AngelLikeMoniBoloni',
#    'wins': 8,
#    'losses': 6,
#    'ties': 0,
#    'points for': 1848.54,
#    'points against': 1794.18,
#    'clinched playoffs': 'Y',
#    'waiver': 10,
#    'moves': 14,
#    'manager': 'Moni'},
#   {'year': 2024,
#    'rank': 3,
#    'team': 'Auto draft',
#    'wins': 9,
#    'losses': 5,
#    'ties': 0,
#    'points for': 1851.2,
#    'points against': 1630.76,
#    'clinched playoffs': 'Y',
#    'waiver': 2,
#    'moves': 6,
#    'manager': 'Shoey'},
#   {'year': 2024,
#    'rank': 4,
#    'team': 'Your Coach',
#    'wins': 8,
#    'losses': 6,
#    'ties': 0,
#    'points for': 1837.44,
#    'points against': 1849.46,
#    'clinched playoffs': 'Y',
#    'waiver': 6,
#    'moves': 26,
#    'manager': 'Marsh'},
#   {'year': 2024,
#    'rank': 5,
#    'team': 'Wieners UpRising',
#    'wins': 7,
#    'losses': 7,
#    'ties': 0,
#    'points for': 1625.16,
#    'points against': 1761.06,
#    'clinched playoffs': 'Y',
#    'waiver': 5,
#    'moves': 31,
#    'manager': 'AK'},
#   {'year': 2024,
#    'rank': 6,
#    'team': 'Natural Athlete',
#    'wins': 8,
#    'losses': 6,
#    'ties': 0,
#    'points for': 1677.28,
#    'points against': 1756.82,
#    'clinched playoffs': 'Y',
#    'waiver': 4,
#    'moves': 27,
#    'manager': 'Burg'},
#   {'year': 2024,
#    'rank': 7,
#    'team': 'Head Coach',
#    'wins': 6,
#    'losses': 8,
#    'ties': 0,
#    'points for': 1709.26,
#    'points against': 1639.86,
#    'clinched playoffs': 'N',
#    'waiver': 3,
#    'moves': 32,
#    'manager': 'Ciggy'},
#   {'year': 2024,
#    'rank': 8,
#    'team': 'Mollywhoppers',
#    'wins': 6,
#    'losses': 8,
#    'ties': 0,
#    'points for': 1757.16,
#    'points against': 1783.24,
#    'clinched playoffs': 'N',
#    'waiver': 8,
#    'moves': 29,
#    'manager': 'Stew'},
#   {'year': 2024,
#    'rank': 9,
#    'team': 'Trash sandwich',
#    'wins': 6,
#    'losses': 8,
#    'ties': 0,
#    'points for': 1690.86,
#    'points against': 1731.92,
#    'clinched playoffs': 'N',
#    'waiver': 1,
#    'moves': 11,
#    'manager': 'Jake'},
#   {'year': 2024,
#    'rank': 10,
#    'team': 'Shmo Stars',
#    'wins': 5,
#    'losses': 9,
#    'ties': 0,
#    'points for': 1745.02,
#    'points against': 1897.12,
#    'clinched playoffs': 'N',
#    'waiver': 7,
#    'moves': 15,
#    'manager': 'Zach'}],
#  'statistics': {'average_rank': [{'manager': '?', 'rank': 12.0},
#    {'manager': 'AK', 'rank': 5.27},
#    {'manager': 'Burg', 'rank': 5.82},
#    {'manager': 'Ciggy', 'rank': 7.36},
#    {'manager': 'Dane', 'rank': 10.0},
#    {'manager': 'Het', 'rank': 9.25},
#    {'manager': 'Jake', 'rank': 5.43},
#    {'manager': 'Kyle', 'rank': 4.0},
#    {'manager': 'Marsh', 'rank': 4.36},
#    {'manager': 'Masi', 'rank': 2.91},
#    {'manager': 'Moni', 'rank': 5.27},
#    {'manager': 'Phil', 'rank': 8.0},
#    {'manager': 'Shoey', 'rank': 4.71},
#    {'manager': 'Stew', 'rank': 6.36},
#    {'manager': 'Zach', 'rank': 6.09}],
#   'top_three_finishes': [{'manager': 'AK',
#     'first': 0,
#     'second': 4,
#     'third': 0,
#     'total': 4,
#     'total seasons': 11,
#     'profit': 100},
#    {'manager': 'Burg',
#     'first': 1,
#     'second': 0,
#     'third': 2,
#     'total': 3,
#     'total seasons': 11,
#     'profit': -300},
#    {'manager': 'Ciggy',
#     'first': 0,
#     'second': 0,
#     'third': 1,
#     'total': 1,
#     'total seasons': 11,
#     'profit': -1000},
#    {'manager': 'Jake',
#     'first': 2,
#     'second': 0,
#     'third': 0,
#     'total': 2,
#     'total seasons': 7,
#     'profit': 500},
#    {'manager': 'Kyle',
#     'first': 0,
#     'second': 1,
#     'third': 0,
#     'total': 1,
#     'total seasons': 3,
#     'profit': 0},
#    {'manager': 'Marsh',
#     'first': 2,
#     'second': 0,
#     'third': 3,
#     'total': 5,
#     'total seasons': 11,
#     'profit': 400},
#    {'manager': 'Masi',
#     'first': 3,
#     'second': 3,
#     'third': 2,
#     'total': 8,
#     'total seasons': 11,
#     'profit': 1800},
#    {'manager': 'Moni',
#     'first': 2,
#     'second': 1,
#     'third': 0,
#     'total': 3,
#     'total seasons': 11,
#     'profit': 400},
#    {'manager': 'Shoey',
#     'first': 0,
#     'second': 1,
#     'third': 2,
#     'total': 3,
#     'total seasons': 7,
#     'profit': -200},
#    {'manager': 'Stew',
#     'first': 0,
#     'second': 0,
#     'third': 1,
#     'total': 1,
#     'total seasons': 11,
#     'profit': -1000},
#    {'manager': 'Zach',
#     'first': 1,
#     'second': 1,
#     'third': 0,
#     'total': 2,
#     'total seasons': 11,
#     'profit': -200}],
#   'playoff_appearances': [{'manager': 'AK',
#     'count': 7,
#     'total seasons': 11,
#     'percentage': 63.6},
#    {'manager': 'Burg', 'count': 7, 'total seasons': 11, 'percentage': 63.6},
#    {'manager': 'Ciggy', 'count': 3, 'total seasons': 11, 'percentage': 27.3},
#    {'manager': 'Jake', 'count': 4, 'total seasons': 7, 'percentage': 57.1},
#    {'manager': 'Kyle', 'count': 3, 'total seasons': 3, 'percentage': 100.0},
#    {'manager': 'Marsh', 'count': 9, 'total seasons': 11, 'percentage': 81.8},
#    {'manager': 'Masi', 'count': 10, 'total seasons': 11, 'percentage': 90.9},
#    {'manager': 'Moni', 'count': 7, 'total seasons': 11, 'percentage': 63.6},
#    {'manager': 'Shoey', 'count': 5, 'total seasons': 7, 'percentage': 71.4},
#    {'manager': 'Stew', 'count': 5, 'total seasons': 11, 'percentage': 45.5},
#    {'manager': 'Zach', 'count': 6, 'total seasons': 11, 'percentage': 54.5}],
#   'highest_season_total': [{'year': 2015,
#     'rank': 12,
#     'manager': '?',
#     'points for': 1450.74},
#    {'year': 2023, 'rank': 2, 'manager': 'AK', 'points for': 1901.92},
#    {'year': 2022, 'rank': 4, 'manager': 'Burg', 'points for': 1829.92},
#    {'year': 2014, 'rank': 3, 'manager': 'Ciggy', 'points for': 1870.04},
#    {'year': 2016, 'rank': 10, 'manager': 'Dane', 'points for': 429.84},
#    {'year': 2015, 'rank': 11, 'manager': 'Het', 'points for': 1602.22},
#    {'year': 2019, 'rank': 1, 'manager': 'Jake', 'points for': 1720.46},
#    {'year': 2015, 'rank': 4, 'manager': 'Kyle', 'points for': 1563.28},
#    {'year': 2018, 'rank': 3, 'manager': 'Marsh', 'points for': 1962.32},
#    {'year': 2022, 'rank': 1, 'manager': 'Masi', 'points for': 2030.34},
#    {'year': 2024, 'rank': 2, 'manager': 'Moni', 'points for': 1848.54},
#    {'year': 2015, 'rank': 8, 'manager': 'Phil', 'points for': 1624.2},
#    {'year': 2018, 'rank': 4, 'manager': 'Shoey', 'points for': 2015.86},
#    {'year': 2014, 'rank': 4, 'manager': 'Stew', 'points for': 1854.68},
#    {'year': 2018, 'rank': 5, 'manager': 'Zach', 'points for': 1815.26}],
#   'highest_weekly_total': [{'year': 2015,
#     'week': 6,
#     'team': 'BALLZ DEEP',
#     'points': 150.14,
#     'estimated points': 107.14,
#     'manager': '?'},
#    {'year': 2017,
#     'week': 15,
#     'team': 'Handy Man Kanaan',
#     'points': 188.0,
#     'estimated points': 130.75,
#     'manager': 'AK'},
#    {'year': 2020,
#     'week': 16,
#     'team': 'CeeDeezNutsAsh',
#     'points': 184.62,
#     'estimated points': 136.57,
#     'manager': 'Burg'},
#    {'year': 2014,
#     'week': 14,
#     'team': 'Down Set Smut',
#     'points': 198.2,
#     'estimated points': 146.36,
#     'manager': 'Ciggy'},
#    {'year': 2016,
#     'week': 1,
#     'team': 'Arken rens',
#     'points': 134.38,
#     'estimated points': 130.42,
#     'manager': 'Dane'},
#    {'year': 2015,
#     'week': 1,
#     'team': 'Chew...PILL!',
#     'points': 177.94,
#     'estimated points': 128.24,
#     'manager': 'Het'},
#    {'year': 2019,
#     'week': 15,
#     'team': 'My team',
#     'points': 192.02,
#     'estimated points': 129.67,
#     'manager': 'Jake'},
#    {'year': 2015,
#     'week': 5,
#     'team': "kyle's Team",
#     'points': 161.34,
#     'estimated points': 103.92,
#     'manager': 'Kyle'},
#    {'year': 2018,
#     'week': 11,
#     'team': 'The Environmentalist',
#     'points': 204.22,
#     'estimated points': 146.48,
#     'manager': 'Marsh'},
#    {'year': 2016,
#     'week': 16,
#     'team': 'Officer Friendly',
#     'points': 208.48,
#     'estimated points': 132.15,
#     'manager': 'Masi'},
#    {'year': 2017,
#     'week': 11,
#     'team': 'JenLuckMeLongTime',
#     'points': 197.58,
#     'estimated points': 142.04,
#     'manager': 'Moni'},
#    {'year': 2015,
#     'week': 8,
#     'team': 'New Kens Russian',
#     'points': 167.82,
#     'estimated points': 128.86,
#     'manager': 'Phil'},
#    {'year': 2018,
#     'week': 8,
#     'team': 'Golden Rams Fam',
#     'points': 199.56,
#     'estimated points': 151.24,
#     'manager': 'Shoey'},
#    {'year': 2020,
#     'week': 2,
#     'team': 'mollywhoppin',
#     'points': 194.1,
#     'estimated points': 130.58,
#     'manager': 'Stew'},
#    {'year': 2015,
#     'week': 15,
#     'team': 'Shmo Stars',
#     'points': 254.8,
#     'estimated points': 136.46,
#     'manager': 'Zach'}],
#   'lowest_weekly_total': [{'year': 2015,
#     'week': 4,
#     'team': 'BALLZ DEEP',
#     'points': 89.68,
#     'estimated points': 110.94,
#     'manager': '?'},
#    {'year': 2022,
#     'week': 5,
#     'team': 'Waiver Wire Wieners',
#     'points': 63.04,
#     'estimated points': 122.46,
#     'manager': 'AK'},
#    {'year': 2021,
#     'week': 16,
#     'team': 'Burg’sHugeDitkaInAsh',
#     'points': 49.14,
#     'estimated points': 97.45,
#     'manager': 'Burg'},
#    {'year': 2015,
#     'week': 16,
#     'team': 'Down Set Smut',
#     'points': 54.74,
#     'estimated points': 91.13,
#     'manager': 'Ciggy'},
#    {'year': 2016,
#     'week': 5,
#     'team': 'Arken rens',
#     'points': 0.0,
#     'estimated points': 0.0,
#     'manager': 'Dane'},
#    {'year': 2016,
#     'week': 14,
#     'team': 'SWOLE Team Six',
#     'points': 67.4,
#     'estimated points': 121.8,
#     'manager': 'Het'},
#    {'year': 2023,
#     'week': 5,
#     'team': 'Trash sandwich',
#     'points': 61.22,
#     'estimated points': 105.13,
#     'manager': 'Jake'},
#    {'year': 2014,
#     'week': 12,
#     'team': 'WE DEM BOYZ',
#     'points': 62.5,
#     'estimated points': 101.29,
#     'manager': 'Kyle'},
#    {'year': 2022,
#     'week': 7,
#     'team': 'Your Coach',
#     'points': 70.9,
#     'estimated points': 128.99,
#     'manager': 'Marsh'},
#    {'year': 2014,
#     'week': 6,
#     'team': 'Officer Friendly',
#     'points': 68.88,
#     'estimated points': 134.19,
#     'manager': 'Masi'},
#    {'year': 2016,
#     'week': 11,
#     'team': 'JenLikeDeezBeforeTs',
#     'points': 61.28,
#     'estimated points': 119.1,
#     'manager': 'Moni'},
#    {'year': 2015,
#     'week': 7,
#     'team': 'New Kens Russian',
#     'points': 74.6,
#     'estimated points': 98.23,
#     'manager': 'Phil'},
#    {'year': 2019,
#     'week': 12,
#     'team': 'Golden Rams Fam',
#     'points': 67.32,
#     'estimated points': 107.75,
#     'manager': 'Shoey'},
#    {'year': 2018,
#     'week': 9,
#     'team': 'mollywhoppin',
#     'points': 70.76,
#     'estimated points': 107.39,
#     'manager': 'Stew'},
#    {'year': 2023,
#     'week': 14,
#     'team': 'Shmo Stars',
#     'points': 67.2,
#     'estimated points': 127.99,
#     'manager': 'Zach'}]}}
